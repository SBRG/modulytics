# %% [markdown]
# # All Gene Scatter Plots
#
# This generates the data for all gene scatter plots for i-modulons in PRECISE 1.0 so that they can be plotted in the ModulomeVis site.

# %%
import sys
# be sure that this points to a clone of github.com/SBRG/ICA
sys.path.append('../../../ica/') 
from icaviz.plotting import *
DATA_DIR = '../../../ica/data/precise_data/'
GENE_DIR = '../../../ica/data/annotation/'
enrich = pd.read_csv(DATA_DIR+'curated_enrichments.csv', index_col = 0)
names = enrich['name'].tolist()
ica_data = load_data(X=DATA_DIR+'log_tpm.csv',
                     S=DATA_DIR+'S.csv',
                     A=DATA_DIR+'A.csv',
                     metadata=DATA_DIR+'metadata.csv',
                     annotation=GENE_DIR+'gene_info.csv',
                     trn=GENE_DIR+'TRN.csv',
                     fasta=GENE_DIR+'NC_000913.3.fasta',
                     cutoff = 550)
pd.set_option('display.max_rows', None)

# %%
from gene_scatter import * #replace py file name

# %%
# this contains the EG numbers for generating URLs to the database
# indexed the same as genes, with "ID" column for EG numbers
locus_to_db = pd.read_csv('locus_to_db.csv',sep='\t', index_col = 1)
import requests
from matplotlib.colors import to_hex

def get_db_link(gene, locus_to_db):
    '''
    input: gene, the b number
           locus_to_db, a df indexed by b number with "ID" column of EG numbers
    output: link to the gene on EcoCyc database
    '''
    # skip gene if it's not in locus_to_db
    if not(gene in locus_to_db.index):
        #print('Gene missing from DB:', gene)
        return np.nan
    
    # generate link
    new_id = locus_to_db.ID[gene]
    link = 'https://ecocyc.org/gene?orgid=ECOLI&id='+new_id
    
    # test link
    request = requests.get(link)
    if request.status_code == 200:
        return link
    else:
        #print('Web site does not exist:', gene, new_id) 
        return np.nan

# %% [markdown]
# ## Working Here

# %%
links = pd.Series(index = ica_data.S.index)
for g in links.index:
    links[g] = get_db_link(g, locus_to_db)

# %%
def gene_scatter_df(ica_data, k, links):
    columns = ['name', 'x', 'y', 'cog', 'color', 'link']
    res = pd.DataFrame(columns = columns, index = ica_data.S.index)
    res.index.name = 'locus'

    cutoff = ica_data.thresholds[k]

    # Draw scatterplot
    res.x = ica_data.X[['control__wt_glc__1','control__wt_glc__2']].mean(axis=1)
    res.y = ica_data.S[k]

    # add other data
    res.name = [ica_data.num2name[l] for l in res.index]
    res.cog = ica_data.gene_info.cog[res.index]
    res.color = [to_hex(ica_data.gene_colors[gene]) for gene in res.index]

    # if the gene is in the i-modulon, it is clickable
    in_im = res.index[res.y.abs()>cutoff]
    for g in in_im:
        res.link[g] = links[g]

    # add a row to store the threshold
    cutoff_row = pd.DataFrame([cutoff] + [np.nan]*5, columns=['thresh'], index = columns).T
    res = pd.concat([cutoff_row, res])

    return res

# %% [markdown]
# ## Generate all CSVs

# %%
data_folder = 'data/'
for k, row in enrich.iterrows():
    this_fig = gene_scatter_df(ica_data, k, links)
    this_fig.to_csv(data_folder + '%i_gene_scatter.csv'%(k))
# Out:
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20 SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
enrich
# Out:
#                          name                          TF  log_odds  \
# component
# 0                        YieP                         NaN       NaN
# 1                        GlpR                        glpR       inf
# 2                        YgbI                         NaN       NaN
# 3                 efeU-repair                         NaN       NaN
# 4                     ydcI-KO                         NaN       NaN
# 5                     BW25113                         NaN       NaN
# 6                      proVWX                         NaN       NaN
# 7                    DhaR/Mlc                    dhaR/mlc  7.459339
# 8                        ArgR                        argR  6.027183
# 9                        YneJ                         NaN       NaN
# 10                       NarL                        narL  6.335376
# 11               e14-deletion                         NaN       NaN
# 12                       MalT                        malT  9.658098
# 13                       OxyR                        oxyR       inf
# 14                      Crp-2                         crp  2.630073
# 15                       AtoC                        atoC       inf
# 16                     PurR-1                        purR  6.595464
# 17                    yheO-KO                         NaN       NaN
# 18                       CsqR                        csqR       inf
# 19                       MetJ                        metJ  7.489086
# 20               entC-menF-KO                         NaN       NaN
# 21          uncharacterized-6                         NaN       NaN
# 22                     PurR-2                        purR  5.744623
# 23                   Cbl+CysB                    cbl+cysB  9.658098
# 24                       GlcC                        glcC       inf
# 25                      Crp-1                         crp  1.712141
# 26                       YiaJ                        yiaJ       inf
# 27                       GcvA                        gcvA  9.371949
# 28                       XylR                        xylR  8.116886
# 29                     fur-KO                         NaN       NaN
# 30                       RpoH                        rpoH       inf
# 31                     GadEWX              gadE+gadW+gadX  8.626688
# 32                translation                         NaN       NaN
# 33                       PrpR                        prpR  8.965973
# 34                      GadWX                   gadX+gadW       inf
# 35                   fimbriae                         NaN       NaN
# 36                       CecR                        cecR       inf
# 37          uncharacterized-4                         NaN       NaN
# 38                     ArcA-1                        arcA  2.767370
# 39            nitrate-related                         NaN       NaN
# 40                        Fnr                         fnr  3.879425
# 41                       CdaR                        cdaR       inf
# 42                   Pyruvate              btsR/ypdB/pdhR  4.598997
# 43                  SrlR+GutM                   srlR+gutM       inf
# 44                  NagC/TyrR                   nagC/tyrR  7.537866
# 45                       CpxR                        cpxR  4.149581
# 46                    thrA-KO                         NaN       NaN
# 47                        Lrp                         lrp  4.953275
# 48                 deletion-1                         NaN       NaN
# 49                    Leu/Ile      ile-tRNA/ilvY/leu-tRNA  9.448668
# 50                 deletion-2                         NaN       NaN
# 51                      Fur-1                         fur  5.496603
# 52          uncharacterized-5                         NaN       NaN
# 53                   Thiamine                         TPP       inf
# 54                       CysB                        cysB  6.720494
# 55                       FliA                        fliA  8.041422
# 56                       PuuR                        puuR       inf
# 57                       NikR                        nikR  9.882264
# 58                  NtrC+RpoN                   ntrC+rpoN  5.771181
# 59                      RcsAB                   rcsA;rcsB  5.886361
# 60                   His-tRNA                    his-tRNA       inf
# 61                      Fur-2                         fur  4.678809
# 62                     Copper              cusR/hprR/cueR       inf
# 63             AllR/AraC/FucR              allR/araC/fucR       inf
# 64                        Cra                         cra  4.812911
# 65                     ArcA-2                        arcA  3.737958
# 66                       EvgA                        evgA  6.476203
# 67          uncharacterized-2                         NaN       NaN
# 68                       Zinc                    zntR/zur       inf
# 69                       SoxS                        soxS  5.100273
# 70                        Nac                         nac  3.801620
# 71                 Tryptophan  L-tryptophan/trpR/trp-tRNA  7.576354
# 72                      curli                         NaN       NaN
# 73                   gadWX-KO                         NaN       NaN
# 74                  flu-yeeRS                         NaN       NaN
# 75          uncharacterized-1                         NaN       NaN
# 76                  FadR/IclR                   fadR/iclR  6.763372
# 77         lipopolysaccharide                         NaN       NaN
# 78                      FlhDC                   flhD;flhC  7.103843
# 79                     crp-KO                         NaN       NaN
# 80                  GntR/TyrR                   gntR/tyrR  7.741869
# 81                    purR-KO                         NaN       NaN
# 82                       RpoS                        rpoS  2.087580
# 83                   membrane                         NaN       NaN
# 84              duplication-1                         NaN       NaN
# 85          uncharacterized-3                         NaN       NaN
# 86                  ExuR/FucR                   exuR/fucR  7.170632
# 87                       FecI                        fecI       inf
# 88               iron-related                         NaN       NaN
# 89                       RbsR                        rbsR  8.495203
# 90                       sgrT                         NaN       NaN
# 91                  insertion                         NaN       NaN
#
#              f1score        pvalue  precision    recall    TP  n_genes  n_tf  \
# component
# 0                NaN           NaN        NaN       NaN   NaN       11     1
# 1           4.000000  0.000000e+00   1.000000  1.000000   9.0        9     1
# 2                NaN           NaN        NaN       NaN   NaN        9     1
# 3                NaN           NaN        NaN       NaN   NaN        8     0
# 4                NaN           NaN        NaN       NaN   NaN        3     0
# 5                NaN           NaN        NaN       NaN   NaN       17     0
# 6                NaN           NaN        NaN       NaN   NaN        4     0
# 7           6.250000  3.570000e-19   0.727273  0.571429   8.0       11     2
# 8          22.500000  6.030000e-18   0.923077  0.098361  12.0       13     1
# 9                NaN           NaN        NaN       NaN   NaN        5     1
# 10         10.888889  1.380000e-40   0.931034  0.228814  27.0       29     1
# 11               NaN           NaN        NaN       NaN   NaN       11     0
# 12          4.750000  2.930000e-22   0.888889  0.800000   8.0        9     1
# 13         13.750000  2.280000e-16   1.000000  0.170213   8.0        8     1
# 14         44.785714  4.250000e-15   0.700000  0.047700  28.0       40     1
# 15          5.000000  1.520000e-12   0.666667  1.000000   4.0        6     1
# 16          8.000000  1.550000e-25   0.812500  0.361111  13.0       16     1
# 17               NaN           NaN        NaN       NaN   NaN       16     0
# 18          6.000000  3.260000e-14   0.500000  1.000000   5.0       10     1
# 19          5.818182  2.010000e-25   0.647059  0.733333  11.0       17     1
# 20               NaN           NaN        NaN       NaN   NaN        3     0
# 21               NaN           NaN        NaN       NaN   NaN       54     0
# 22         13.142857  3.480000e-13   0.700000  0.194444   7.0       10     1
# 23          4.750000  2.930000e-22   0.800000  0.888889   8.0       10     2
# 24          4.333333  1.390000e-18   1.000000  0.857143   6.0        6     1
# 25         44.620690  7.330000e-10   0.483333  0.049404  29.0       60     1
# 26          4.200000  4.680000e-29   1.000000  0.909091  10.0       10     1
# 27          5.333333  1.590000e-09   0.750000  0.750000   3.0        4     1
# 28          6.666667  2.380000e-15   0.461538  0.857143   6.0       13     1
# 29               NaN           NaN        NaN       NaN   NaN       13     0
# 30         22.923077  5.900000e-20   1.000000  0.095588  13.0       13     1
# 31          5.600000  9.080000e-25   0.588235  0.909091  10.0       17     3
# 32               NaN           NaN        NaN       NaN   NaN       24     0
# 33          5.500000  7.610000e-12   0.666667  0.800000   4.0        6     1
# 34          5.750000  4.660000e-21   1.000000  0.533333   8.0        8     2
# 35               NaN           NaN        NaN       NaN   NaN        8     0
# 36          4.000000  0.000000e+00   1.000000  1.000000   5.0        5     1
# 37               NaN           NaN        NaN       NaN   NaN       10     0
# 38         30.545455  6.420000e-20   0.660000  0.072687  33.0       50     1
# 39               NaN           NaN        NaN       NaN   NaN       14     0
# 40         28.294118  3.370000e-27   0.850000  0.077098  34.0       40     1
# 41          4.222222  1.660000e-26   0.900000  1.000000   9.0       10     1
# 42          0.156863  8.490000e-07   0.500000  0.093023   4.0        8     3
# 43          4.800000  2.720000e-15   1.000000  0.714286   5.0        5     2
# 44          8.250000  3.870000e-31   0.941176  0.326531  16.0       17     2
# 45         19.750000  5.320000e-11   0.470588  0.129032   8.0       17     1
# 46               NaN           NaN        NaN       NaN   NaN        3     0
# 47         14.812500  1.260000e-37   0.864865  0.160000  32.0       37     1
# 48               NaN           NaN        NaN       NaN   NaN       41     0
# 49          4.769231  4.060000e-33   0.928571  0.764706  13.0       14     3
# 50               NaN           NaN        NaN       NaN   NaN      110     0
# 51         10.372093  5.460000e-55   0.895833  0.245714  43.0       48     1
# 52               NaN           NaN        NaN       NaN   NaN        4     0
# 53          4.000000  0.000000e+00   1.000000  1.000000  11.0       11     1
# 54          6.500000  4.120000e-32   0.761905  0.516129  16.0       21     1
# 55          6.551724  4.460000e-54   0.966667  0.446154  29.0       30     1
# 56          4.000000  0.000000e+00   1.000000  1.000000   7.0        7     1
# 57          4.800000  4.660000e-15   0.833333  0.833333   5.0        6     1
# 58          6.500000  2.690000e-52   0.571429  0.666667  32.0       56     2
# 59          8.800000  4.360000e-19   0.357143  0.625000  10.0       28     1
# 60          4.250000  6.520000e-24   0.888889  1.000000   8.0        9     1
# 61         18.363636  3.460000e-26   0.814815  0.125714  22.0       27     1
# 62          6.750000  5.470000e-20   1.000000  0.421053   8.0        8     3
# 63          5.333333  1.190000e-41   1.000000  0.600000  18.0       18     3
# 64         25.000000  7.060000e-16   0.800000  0.088889  12.0       15     1
# 65         45.619048  1.150000e-16   0.840000  0.046256  21.0       25     1
# 66          7.200000  6.200000e-21   0.500000  0.625000  10.0       20     1
# 67               NaN           NaN        NaN       NaN   NaN       42     0
# 68          5.428571  2.810000e-19   0.583333  1.000000   7.0       12     2
# 69          8.173913  6.760000e-35   0.560976  0.433962  23.0       41     1
# 70         34.687500  7.120000e-24   0.864865  0.061776  32.0       37     1
# 71          6.444444  4.430000e-21   0.818182  0.500000   9.0       11     3
# 72               NaN           NaN        NaN       NaN   NaN        4     0
# 73               NaN           NaN        NaN       NaN   NaN        2     0
# 74               NaN           NaN        NaN       NaN   NaN        8     0
# 75               NaN           NaN        NaN       NaN   NaN       15     0
# 76          7.600000  3.930000e-21   0.769231  0.400000  10.0       13     2
# 77               NaN           NaN        NaN       NaN   NaN       36     0
# 78          6.263158  4.760000e-66   0.926829  0.487179  38.0       41     1
# 79               NaN           NaN        NaN       NaN   NaN       14     0
# 80          6.000000  3.180000e-29   0.866667  0.541667  13.0       15     2
# 81               NaN           NaN        NaN       NaN   NaN        3     0
# 82         20.500000  1.100000e-18   0.373832  0.132013  40.0      107     1
# 83               NaN           NaN        NaN       NaN   NaN       15     0
# 84               NaN           NaN        NaN       NaN   NaN       84     0
# 85               NaN           NaN        NaN       NaN   NaN        2     0
# 86          6.200000  1.020000e-22   0.666667  0.625000  10.0       15     2
# 87          6.000000  3.260000e-14   0.500000  1.000000   5.0       10     1
# 88               NaN           NaN        NaN       NaN   NaN       20     0
# 89          6.000000  9.780000e-14   0.833333  0.555556   5.0        6     1
# 90               NaN           NaN        NaN       NaN   NaN        4     0
# 91               NaN           NaN        NaN       NaN   NaN        9     0
#
#                                                    Regulator  \
# component
# 0                                                       YieP
# 1                                                       GlpR
# 2                                                       YgbI
# 3                                                        NaN
# 4                                                        NaN
# 5                                                        NaN
# 6                                                        NaN
# 7                                                DhaR or Mlc
# 8                                                       ArgR
# 9                                                       YneJ
# 10                                                      NarL
# 11                                                       NaN
# 12                                                      MalT
# 13                                                      OxyR
# 14                                                       Crp
# 15                                                      AtoC
# 16                                                      PurR
# 17                                                       NaN
# 18                                                      CsqR
# 19                                                      MetJ
# 20                                                       NaN
# 21                                                       NaN
# 22                                                      PurR
# 23                                              Cbl and CysB
# 24                                                      GlcC
# 25                                                       Crp
# 26                                                      YiaJ
# 27                                                      GcvA
# 28                                                      XylR
# 29                                                       NaN
# 30                                                      RpoH
# 31                                    GadE and GadW and GadX
# 32                                                       NaN
# 33                                                      PrpR
# 34                                             GadW and GadX
# 35                                                       NaN
# 36                                                      CecR
# 37                                                       NaN
# 38                                                      ArcA
# 39                                                       NaN
# 40                                                       Fnr
# 41                                                      CdaR
# 42                                      BtsR or YpdB or PdhR
# 43                                             SrlR and GutM
# 44                                              NagC or TyrR
# 45                                                      CpxR
# 46                                                       NaN
# 47                                                       Lrp
# 48                                                       NaN
# 49         IlvY or leu-tRNA attenuation or ile-tRNA atten...
# 50                                                       NaN
# 51                                                       Fur
# 52                                                       NaN
# 53                                                  Thiamine
# 54                                                      CysB
# 55                                                      FliA
# 56                                                      PuuR
# 57                                                      NikR
# 58                                             NtrC and RpoN
# 59                                                     RcsAB
# 60                                      His-tRNA attenuation
# 61                                                       Fur
# 62                                      CusR or HprR or CueR
# 63                                      AllR or AraC or FucR
# 64                                                       Cra
# 65                                                      ArcA
# 66                                                      EvgA
# 67                                                       NaN
# 68                                               ZntR or Zur
# 69                                                      SoxS
# 70                                                       Nac
# 71         TrpR or trp-tRNA attenuation or Tryptophan att...
# 72                                                       NaN
# 73                                                       NaN
# 74                                                       NaN
# 75                                                       NaN
# 76                                              FadR or IclR
# 77                                                       NaN
# 78                                                     FlhDC
# 79                                                       NaN
# 80                                              GntR or TyrR
# 81                                                       NaN
# 82                                                      RpoS
# 83                                                       NaN
# 84                                                       NaN
# 85                                                       NaN
# 86                                              ExuR or FucR
# 87                                                      FecI
# 88                                                       NaN
# 89                                                      RbsR
# 90                                                       NaN
# 91                                                       NaN
#
#                                                     Function  \
# component
# 0                                                    Unknown
# 1                                        Glycerol catabolism
# 2                                           Unknown Function
# 3          Accounts for repair and expression of efeU operon
# 4                                Accounts for ydcI knock-out
# 5          Transcriptional difference between BW25113 and...
# 6                                  Glycine betaine transport
# 7          Dihydroxyacetone kinase and phosphotransferase...
# 8                                      Arginine biosynthesis
# 9                                           Unknown Function
# 10                                       Nitrate respiration
# 11                                   Removal of e14 prophage
# 12                                        Maltose catabolism
# 13                                       Peroxide reductases
# 14                          Various carbon source catabolism
# 15                                  Acetoacetate degradation
# 16                                       Purine Biosynthesis
# 17                               Accounts for yheO knock-out
# 18                                 Sulfoquinovose catabolism
# 19                                   Methionine biosynthesis
# 20                     Accounts for entC and menF knock-outs
# 21                                          Unknown Function
# 22                                   Pyrimidine biosynthesis
# 23                           Aliphatic sulfonate utilization
# 24                                      Glycolate catabolism
# 25                                   Miscellaneous functions
# 26                                     Ascorbate utilization
# 27                                   Glycine cleavage system
# 28                                         Xylose catabolism
# 29                                Accounts for fur knock-out
# 30                                       Heat shock response
# 31                                      Acid stress response
# 32                         Enriched in translation machinery
# 33                                     Propionate catabolism
# 34                                      Acid stress response
# 35                                         Fimbriae assembly
# 36                         Related to antibiotic sensitivity
# 37                                          Unknown Function
# 38                                        Anaerobic response
# 39                                     Nitric oxide response
# 40                                        Anaerobic response
# 41                                      Glucarate catabolism
# 42                         Pyruvate transport and metabolism
# 43                                       Sorbitol catabolism
# 44         N-acetylglucosamine catabolism and tyrosine bi...
# 45                                  Various stress responses
# 46                               Accounts for thrA knock-out
# 47                          Amino acid and peptide transport
# 48               Large deletion of 39 genes during evolution
# 49                    Branched-chain amino acid biosynthesis
# 50              Large deletion of 171 genes during evolution
# 51                                          Iron homeostasis
# 52                                          Unknown Function
# 53                                     Thiamine biosynthesis
# 54                            Inorganic sulfate assimilation
# 55                                                Chemotaxis
# 56                                     Putrescine catabolism
# 57                                        Nickel homeostasis
# 58                              Nitrogen starvation response
# 59                            Colanic acid capsule formation
# 60                                    Histidine biosynthesis
# 61                                          Iron homeostasis
# 62                                        Copper homeostasis
# 63         Allantoin, glyoxylate, L-arabinose, and L-fuco...
# 64                                 Central carbon metabolism
# 65                                  Electron Transport Chain
# 66                          Acid and osmotic stress response
# 67                                          Unknown Function
# 68                                          Zinc homeostasis
# 69                                 Oxidative stress response
# 70                              Nitrogen starvation response
# 71                                   Tryptophan Biosynthesis
# 72                                            Curli assembly
# 73                     Accounts for gadW and gadX knock-outs
# 74                                  Genes in CP4-44 prophage
# 75                                          Unknown Function
# 76                                    Fatty acid degradation
# 77                           Lipopolysaccharide biosynthesis
# 78                                         Flagella assembly
# 79                                Accounts for crp knock-out
# 80            Gluconate catabolism and tyrosine biosynthesis
# 81                               Accounts for purR knock-out
# 82                                   General stress response
# 83                       Enriched in membrane-bound proteins
# 84           Large duplication of 129 genes during evolution
# 85                                          Unknown Function
# 86                   D-galacturonate and L-fucose catabolism
# 87                                  Ferric citrate transport
# 88                                Related to iron metabolism
# 89                                       D-ribose catabolism
# 90                     Contains single dominating gene: sgrT
# 91          IS2 insertion element after laboratory evolution
#
#                                          Category  threshold
# component
# 0                             Regulator Discovery   0.089767
# 1                       Carbon Source Utilization   0.066801
# 2                             Regulator Discovery   0.082240
# 3                             Genomic Alterations   0.150925
# 4                             Genomic Alterations   0.099229
# 5                             Genomic Alterations   0.085425
# 6                           Biological Enrichment   0.117523
# 7                       Carbon Source Utilization   0.104547
# 8          Amino Acid and Nucleotide Biosynthesis   0.080441
# 9                             Regulator Discovery   0.114203
# 10                              Energy Metabolism   0.070843
# 11                            Genomic Alterations   0.102573
# 12                      Carbon Source Utilization   0.092357
# 13                                Stress Response   0.108527
# 14                      Carbon Source Utilization   0.048188
# 15                       Miscellaneous Metabolism   0.105756
# 16         Amino Acid and Nucleotide Biosynthesis   0.089382
# 17                            Genomic Alterations   0.078511
# 18                       Miscellaneous Metabolism   0.097160
# 19         Amino Acid and Nucleotide Biosynthesis   0.088894
# 20                            Genomic Alterations   0.107709
# 21                                Uncharacterized   0.052578
# 22         Amino Acid and Nucleotide Biosynthesis   0.094276
# 23                       Miscellaneous Metabolism   0.104230
# 24                      Carbon Source Utilization   0.135030
# 25                       Miscellaneous Metabolism   0.052331
# 26                      Carbon Source Utilization   0.114667
# 27                       Miscellaneous Metabolism   0.115085
# 28                      Carbon Source Utilization   0.089467
# 29                            Genomic Alterations   0.078193
# 30                                Stress Response   0.098587
# 31                                Stress Response   0.047196
# 32                          Biological Enrichment   0.068836
# 33                      Carbon Source Utilization   0.107696
# 34                                Stress Response   0.135485
# 35                          Biological Enrichment   0.110652
# 36                                Stress Response   0.149862
# 37                                Uncharacterized   0.074349
# 38                              Energy Metabolism   0.058051
# 39                          Biological Enrichment   0.078067
# 40                              Energy Metabolism   0.056672
# 41                      Carbon Source Utilization   0.083043
# 42                      Carbon Source Utilization   0.081747
# 43                      Carbon Source Utilization   0.144755
# 44                      Carbon Source Utilization   0.080381
# 45                                Stress Response   0.076827
# 46                            Genomic Alterations   0.124971
# 47         Amino Acid and Nucleotide Biosynthesis   0.059078
# 48                            Genomic Alterations   0.064100
# 49         Amino Acid and Nucleotide Biosynthesis   0.092564
# 50                            Genomic Alterations   0.047048
# 51                              Metal Homeostasis   0.052827
# 52                                Uncharacterized   0.079179
# 53                       Miscellaneous Metabolism   0.084444
# 54         Amino Acid and Nucleotide Biosynthesis   0.071390
# 55                          Structural Components   0.052255
# 56                       Miscellaneous Metabolism   0.112615
# 57                              Metal Homeostasis   0.107243
# 58                                Stress Response   0.031952
# 59                          Structural Components   0.068513
# 60         Amino Acid and Nucleotide Biosynthesis   0.122577
# 61                              Metal Homeostasis   0.083696
# 62                              Metal Homeostasis   0.062442
# 63                      Carbon Source Utilization   0.086996
# 64                      Carbon Source Utilization   0.061719
# 65                              Energy Metabolism   0.081113
# 66                                Stress Response   0.066655
# 67                                Uncharacterized   0.056562
# 68                              Metal Homeostasis   0.063291
# 69                                Stress Response   0.057737
# 70                                Stress Response   0.063896
# 71         Amino Acid and Nucleotide Biosynthesis   0.103084
# 72                          Biological Enrichment   0.141526
# 73                            Genomic Alterations   0.244311
# 74                          Biological Enrichment   0.086598
# 75                                Uncharacterized   0.088147
# 76                       Miscellaneous Metabolism   0.083118
# 77                          Biological Enrichment   0.058069
# 78                          Structural Components   0.047920
# 79                            Genomic Alterations   0.096790
# 80                      Carbon Source Utilization   0.080781
# 81                            Genomic Alterations   0.119782
# 82                                Stress Response   0.040188
# 83                          Biological Enrichment   0.095678
# 84                            Genomic Alterations   0.060914
# 85                                Uncharacterized   0.137902
# 86                      Carbon Source Utilization   0.077028
# 87                              Metal Homeostasis   0.084341
# 88                          Biological Enrichment   0.070082
# 89                      Carbon Source Utilization   0.102902
# 90                          Biological Enrichment   0.100564
# 91                            Genomic Alterations   0.096214
