# %% [markdown]
# # All Gene Tables
#
# This generates the data for all gene tables for i-modulons in PRECISE 1.0 so that they can be plotted in the ModulomeVis site.

# %%
import sys
# be sure that this points to a clone of github.com/SBRG/ICA
sys.path.append('../../../ica/') 
from icaviz.plotting import *
DATA_DIR = '../../../ica/data/precise_data/'
GENE_DIR = '../../../ica/data/annotation/'
enrich = pd.read_csv(DATA_DIR+'curated_enrichments.csv', index_col = 0)
names = enrich['name'].tolist()
ica_data = load_data(X=DATA_DIR+'log_tpm.csv',
                     S=DATA_DIR+'S.csv',
                     A=DATA_DIR+'A.csv',
                     metadata=DATA_DIR+'metadata.csv',
                     annotation=GENE_DIR+'gene_info.csv',
                     trn=GENE_DIR+'TRN.csv',
                     fasta=GENE_DIR+'NC_000913.3.fasta',
                     cutoff = 550)
pd.set_option('display.max_rows', None)

# %%
from gene_table import * 

# this contains the EG numbers for generating URLs to the database
# indexed the same as genes, with "ID" column for EG numbers
locus_to_db = pd.read_csv('locus_to_db.csv',sep='\t', index_col = 1)

# %% [markdown]
# ## Generate all CSVs

# %%
k = 1 
data_folder = 'data/'
row = enrich.loc[k]

this_fig = gene_table_df(ica_data, k, row, locus_to_db) 

this_fig.TF = [s.replace(',', ', ') for s in this_fig.TF]
this_fig.operon = [s.replace(',', ', ') for s in this_fig.operon]
# Out:
#            comp gene_name                                            product  \
# locus
# b2241  0.375662      glpA  anaerobic glycerol-3-phosphate dehydrogenase s...
# b3426  0.350034      glpD        glycerol-3-phosphate dehydrogenase, aerobic
# b2242  0.328961      glpB  anaerobic glycerol-3-phosphate dehydrogenase s...
# b2243  0.315752      glpC  anaerobic glycerol-3-phosphate dehydrogenase s...
# b3927  0.312307      glpF                              glycerol channel GlpF
# b2240  0.306134      glpT          glycerol-3-phosphate:phosphate antiporter
# b3926  0.290235      glpK                                    glycerol kinase
# b2239  0.211384      glpQ  glycerophosphoryl diester phosphodiesterase, p...
# b3925  0.084278      glpX                     fructose 1,6-bisphosphatase II
#
#                operon                                             TF  glpR  \
# locus
# b2241  glpA,glpB,glpC  Sigma70, arcA, crp, fis, flhD;flhC, fnr, glpR  True
# b3426            glpD                 Sigma70, arcA, crp, glpR, yieP  True
# b2242  glpA,glpB,glpC  Sigma70, arcA, crp, fis, flhD;flhC, fnr, glpR  True
# b2243  glpA,glpB,glpC  Sigma70, arcA, crp, fis, flhD;flhC, fnr, glpR  True
# b3927  glpF,glpK,glpX                             Sigma70, crp, glpR  True
# b2240       glpT,glpQ         Sigma70, crp, fis, fnr, glpR, ihf, nac  True
# b3926  glpF,glpK,glpX                             Sigma70, crp, glpR  True
# b2239       glpT,glpQ         Sigma70, crp, fis, fnr, glpR, ihf, nac  True
# b3925  glpF,glpK,glpX                             Sigma70, crp, glpR  True
#
#                                                  link
# locus
# b2241  https://ecocyc.org/gene?orgid=ECOLI&id=EG10391
# b3426  https://ecocyc.org/gene?orgid=ECOLI&id=EG10394
# b2242  https://ecocyc.org/gene?orgid=ECOLI&id=EG10392
# b2243  https://ecocyc.org/gene?orgid=ECOLI&id=EG10393
# b3927  https://ecocyc.org/gene?orgid=ECOLI&id=EG10396
# b2240  https://ecocyc.org/gene?orgid=ECOLI&id=EG10401
# b3926  https://ecocyc.org/gene?orgid=ECOLI&id=EG10398
# b2239  https://ecocyc.org/gene?orgid=ECOLI&id=EG10399
# b3925  https://ecocyc.org/gene?orgid=ECOLI&id=EG11517

# %%
data_folder = 'data/'
for k, row in enrich.iterrows():
    this_fig = gene_table_df(ica_data, k, row, locus_to_db) 
    this_fig.to_csv(data_folder + '%i_gene_table.csv'%(k))
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Gene missing from DB: b4490_2
# Gene missing from DB: b2092_2
# Gene missing from DB: b2092_1
# Gene missing from DB: b4498_1
# Gene missing from DB: b0553_1
# Gene missing from DB: b4640_1
# Gene missing from DB: b0562_2
# Gene missing from DB: b0553_1
# Gene missing from DB: b2681_1
# Gene missing from DB: b2092_2
# Gene missing from DB: b4582_1
# Gene missing from DB: b4488_2
# Gene missing from DB: b4488_1
# Gene missing from DB: b4493_2
# Gene missing from DB: b4493_1
# Gene missing from DB: b4492_3
# Gene missing from DB: b1459_1
# Gene missing from DB: b4492_1
# Gene missing from DB: b4582_1
# Gene missing from DB: b4640_1
# Gene missing from DB: b3643_1
# Gene missing from DB: b3268_2
# Gene missing from DB: b4490_2
# Gene missing from DB: b4646_2
# Gene missing from DB: b4571_1
# Gene missing from DB: b4659_2
# Gene missing from DB: b4571_2
# Gene missing from DB: b4038_3
# Gene missing from DB: b3423_1
# Gene missing from DB: b2681_1
# Gene missing from DB: b3643_1
# Gene missing from DB: b4490_2
# Gene missing from DB: b4640_1
