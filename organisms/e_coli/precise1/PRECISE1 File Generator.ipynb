# %% [markdown]
# # PRECISE 1.0 File Generator
#
# This notebook generates all files for the Modulytics web page of E. coli, based on ICA of the PRECISE RNA-seq database.

# %%
import sys
# be sure that this points to a clone of github.com/SBRG/ICA
# which is the source of data in this case
sys.path.append('../../../../ica/') 
from icaviz.plotting import *
DATA_DIR = '../../../../ica/data/precise_data/'
GENE_DIR = '../../../../ica/data/annotation/'
enrich = pd.read_csv(DATA_DIR+'curated_enrichments.csv', index_col = 0)
names = enrich['name'].tolist()
ica_data = load_data(X=DATA_DIR+'log_tpm.csv',
                     S=DATA_DIR+'S.csv',
                     A=DATA_DIR+'A.csv',
                     metadata=DATA_DIR+'metadata.csv',
                     annotation=GENE_DIR+'gene_info.csv',
                     trn=GENE_DIR+'TRN.csv',
                     fasta=GENE_DIR+'NC_000913.3.fasta',
                     cutoff = 550,
                     organism='ecoli')
pd.set_option('display.max_rows', None)

# %%
# get functions from py files
sys.path.append('../../../py')
from gene_table import *
from gene_histogram import *
from gene_scatter import *
from activity_bar import *
from regulon_venn import *
from regulon_scatter import *

# gene dashboards
# from perGene_table import *
from gene_activity_bar import *

import os

# %%
# read in other necessary annotation files
locus_to_db = pd.read_csv('../annotation/locus_to_db.csv',sep='\t', index_col = 1)
links = pd.read_csv('../annotation/gene_links.csv', index_col = 0, header = None).to_dict()[1]
sample_meta = pd.read_csv('sample_metadata.csv', index_col = 0)
tf_links = pd.read_csv('../annotation/tf_links.csv', index_col = 1, header=None).to_dict()[2]
gene_info = pd.read_csv(GENE_DIR+'gene_info.csv', index_col = 0)
trn = pd.read_csv(GENE_DIR+'TRN.csv', index_col = 0)

# %% [markdown]
# ## Generate Sample Meta and TF_links, if necessary
#
# Sample_metadata is simply the metadata table with all non-public columns removed.

# %%
# public metadata table

# drop the stuff the public doesn't need to see
sample_meta = ica_data.metadata.drop(['contact', 'library creator', 'run_date', 'R1', 'R2', 'BAM', 'alignment', 'Public'], axis=1)

# fix a minor issue with the number of biological replicates in a condition
sample_meta.loc[(sample_meta.project_id == 'ica') & (sample_meta.condition_id == 'wt_glc'), 'Biological Replicates'] = [6]*6

# reset index so that javascript can deal more easily (as numerically indexed arrays)
sample_meta = sample_meta.reset_index()

#sample_meta.to_csv('data/sample_metadata.csv')

# %% [markdown]
# I created the following csv and then **manually** annotated each TF with a relevant link in RegulonDB. I would need another mapping file, like locus_to_db, in order to auto generate this for all TFs.
#
# Note that RegulonDB is often very slow, so these may in the future be replaced with ecocyc links.

# %%
all_tfs = []

for k, row in enrich.iterrows():
    if type(row.TF) == str:
        if '/' in row.TF:
            all_tfs += row.TF.split('/')
        elif '+' in row.TF:
            all_tfs += row.TF.split('+')
        else:
            all_tfs += [row.TF]
all_tfs = pd.Series(all_tfs).drop_duplicates()
#all_tfs.to_csv('../annotation/tf_links.csv')

# %% [markdown]
# ## Generate Files

# %%
# dataset_meta: Stores information for the header of the dataset page
dataset_meta = pd.Series({'Title':'<i>E. Coli</i> PRECISE',
                          'Organism': '<i>Escherichia Coli</i> K-12',
                          'Strain': 'MG1655 and BW25113',
                          'Publication':'<a href="https://www.nature.com/articles/s41467-019-13483-w">Sastry, et al., 2019</a>'})
dataset_meta.to_csv('dataset_meta.csv')
# Out:
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.

# %%
# iM_table: this is the main component of the dataset page

cat_order = ['Carbon Source Utilization', 
             'Amino Acid and Nucleotide Biosynthesis',
             'Energy Metabolism',
             'Metal Homeostasis',
             'Miscellaneous Metabolism',
             'Structural Components',
             'Stress Response',
             'Regulator Discovery',
             'Biological Enrichment',
             'Genomic Alterations',
             'Uncharacterized']

cat_dict = {cat_order[i]:i for i in range(len(cat_order))}

im_table = enrich[['name', 'Regulator', 'Function', 'Category', 'n_genes', 'precision', 'recall']]
im_table = im_table.rename(columns={'name':'Name'})
im_table.index.name = 'k'
im_table['category_num'] = [cat_dict[im_table.Category[k]] for k in im_table.index]
im_table.to_csv('iM_table.csv')

# %%
num_ims = im_table.shape[0]-1
file = open('num_ims.txt', 'w')
file.write(str(num_ims))
file.close()

# %%
# This function is needed to create the header for each iModulon
def tf_with_links(k, row, tf_links):
    tf_str = row.TF

    if not(type(tf_str) == str):
        return tf_str

    # get a list of transcription factors
    and_or = ''
    if '/' in tf_str:
        and_or = ' or '
        tfs = tf_str.split('/')
    elif '+' in tf_str:
        and_or = ' and '
        tfs = tf_str.split('+')
    else:
        tfs = [tf_str]

    # start building an html string
    tfs_html = []
    for tf in tfs:
        if tf in tf_links.keys():
            link = tf_links[tf]
            if type(link)==str:# this tf has a link
                tf_ = '<a href="' + link + '" target="_blank">'+ tf + '</a>'
                tfs_html += [tf_]
            else: # this tf has no link
                tfs_html += [tf]
        # this tf isn't in the tf_links file
        else:
            tfs_html += [tf]
    res = and_or.join(tfs_html)
    return res

# %%
# This function generates all necessary files for a single iModulon
def make_directory(ica_data, k, row, links, sample_meta, tf_links):
    # generate the plot files
    gene_table = gene_table_df(ica_data, k, row, links = links)
    gene_hist = gene_hist_df(ica_data, k, row)
    base_conds = ['control__wt_glc__1','control__wt_glc__2']
    gene_scatter = gene_scatter_df(ica_data, k, base_conds, links)
    act_bar = activity_bar_df(ica_data, k, sample_meta)

    reg_venn = regulon_venn_df(ica_data, k, row)
    reg_scatter = regulon_scatter_df(ica_data, k, row)

    # generate a basic data df
    res = pd.Series(index=['name', 'TF', 'Regulator',
                           'Function', 'Category', 
                           'has_venn', 'scatter', 'has_meme'])
    res.loc['name'] = row.loc['name']
    res.loc['TF'] = row.TF
    res.loc['Regulator'] = tf_with_links(k, row, tf_links)
    res.loc['Function'] = row.Function
    res.loc['Category'] = row.Category
    res.loc['has_venn'] = not(reg_venn is None)
    if reg_scatter is None:
        res.loc['scatter'] = 0
    else:
        res.loc['scatter'] = reg_scatter.shape[1] - 1
    res.loc['has_meme'] = False # update later
    # may also want to add the stats from enrich

    # save output
    folder = 'iModulon_files/'+str(k)+'/'
    if not(os.path.isdir(folder)):
        os.mkdir(folder)
    res.to_csv(folder+str(k)+'_meta.csv')
    gene_table.to_csv(folder+str(k)+'_gene_table.csv')
    gene_hist.to_csv(folder+str(k)+'_gene_hist.csv')
    gene_scatter.to_csv(folder+str(k)+'_gene_scatter.csv')
    act_bar.to_csv(folder+str(k)+'_activity_bar.csv')
    if not(reg_venn is None):
        reg_venn.to_csv(folder+str(k)+'_reg_venn.csv')
    if not(reg_scatter is None):
        reg_scatter.to_csv(folder+str(k)+'_reg_scatter.csv')
    ica_data.S[k].to_csv(folder+str(k)+'_gene_weights.csv')
    ica_data.A.loc[k].to_csv(folder+str(k)+'_activity.csv')

# %%
for k, row in enrich.iterrows():
    make_directory(ica_data, k, row, links, sample_meta, tf_links)
# Out:
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ...
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]

# %% [markdown]
# # Gene Files

# %%
# Information for Gene Metadata

def make_gene_files(ica_data, k, row, links, sample_meta, tf_links):

    # generate metadata df
    res = pd.Series(index=['bNum', 'name', 'operon', 'product',
                           'cog', 'regulator(s)'])
    res.loc['bNum'] = k
    res.loc['name'] = row.gene_name
    res.loc['operon'] = row.operon
    res.loc['product'] = row['product']
    res.loc['cog'] = row.cog
    res.loc['regulator(s)'] = ", ".join(trn[trn.gene_id == k].TF.to_list())
    
    # save output
    folder = 'gene_page_files/'+str(k)+'/'
    if not(os.path.isdir(folder)):
        os.mkdir(folder)
    res.to_csv(folder+str(k)+'_meta.csv')
    
    #activity plot
    this_fig = gene_activity_bar_df(ica_data, k, sample_meta)
    this_fig.to_csv(data_folder + k + '_activity_bar.csv')

# %%
for k, row in gene_info.iterrows():
    make_gene_files(ica_data, k, row, links, sample_meta, tf_links)
# Out:
# C:\Users\Katherine\anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   import sys
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4410             try:
# -> 4411                 return libindex.get_value_at(s, key)
#    4412             except IndexError:
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_at()
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_at()
#
# pandas\_libs\util.pxd in pandas._libs.util.get_value_at()
#
# pandas\_libs\util.pxd in pandas._libs.util.validate_indexer()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-f4d406149dff> in <module>
#       1 for k, row in gene_info.iterrows():
# ----> 2     make_gene_files(ica_data, k, row, links, sample_meta, tf_links)
#
# <ipython-input-6-cd7c9e358646> in make_gene_files(ica_data, k, row, links, sample_meta, tf_links)
#       9     res.loc['name'] = row.gene_name
#      10     res.loc['operon'] = row.operon
# ---> 11     res.loc['product'] = row['product']
#      12     res.loc['cog'] = row.cog
#      13     res.loc['regulator(s)'] = ", ".join(trn[trn.gene_id == k].TF.to_list())
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4417                     raise InvalidIndexError(key)
#    4418                 else:
# -> 4419                     raise e1
#    4420             except Exception:
#    4421                 raise e1
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4403         k = self._convert_scalar_indexer(k, kind="getitem")
#    4404         try:
# -> 4405             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4406         except KeyError as e1:
#    4407             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'product'

# %% [markdown]
# ### make json file for Search

# %%
# Get df in correct format
gene_df = gene_info.copy()
gene_df["bNum"] = gene_info.index
gene_df = gene_df[['gene_name', "bNum", "product"]]
gene_df = gene_df.sort_values(by="gene_name").fillna(value = "unknown gene product")

gene_df.to_json('./gene_page_files/gene_list.json', orient="records")

# %%
gene_info
# Out:
#            start     stop strand gene_name  length  \
# b0001        189      255      +      thrL      66
# b0002        336     2799      +      thrA    2463
# b0003       2800     3733      +      thrB     933
# b0004       3733     5020      +      thrC    1287
# b0005       5233     5530      +      yaaX     297
# b0006       5682     6459      -      yaaA     777
# b0007       6528     7959      -      yaaJ    1431
# b0008       8237     9191      +      talB     954
# b0009       9305     9893      +       mog     588
# b0010       9927    10494      -      satP     567
# b0011      10642    11356      -      yaaW     714
# b0013      11381    11786      -      yaaI     405
# b0014      12162    14079      +      dnaK    1917
# b0015      14167    15298      +      dnaJ    1131
# b0016      15444    16557      +     insL1    1113
# b0018      16750    16960      -      mokC     210
# b4412      16750    16903      -      hokC     153
# b0019      17488    18655      +      nhaA    1167
# b0020      18714    19620      +      nhaR     906
# b0021      19810    20314      -     insB1     504
# b0022      20232    20508      -      insA     276
# b0023      20814    21078      -      rpsT     264
# b0024      21180    21399      +      yaaY     219
# b0025      21406    22348      +      ribF     942
# b0026      22390    25207      +      ileS    2817
# b0027      25206    25701      +      lspA     495
# b0028      25825    26275      +      fkpB     450
# b0029      26276    27227      +      ispH     951
# b0030      27292    28207      +      rihC     915
# b0031      28373    29195      +      dapB     822
# b0032      29650    30799      +      carA    1149
# b0033      30816    34038      +      carB    3222
# b0034      34299    34695      +      caiF     396
# b0035      34780    35371      -      caiE     591
# b0036      35376    36162      -      caiD     786
# b0037      36270    37824      -      caiC    1554
# b0038      37897    39115      -      caiB    1218
# b0039      39243    40386      -      caiA    1143
# b0040      40416    41931      -      caiT    1515
# b0041      42402    43173      +      fixA     771
# b0042      43187    44129      +      fixB     942
# b0043      44179    45466      +      fixC    1287
# b0044      45462    45750      +      fixX     288
# b0045      45806    47138      +      yaaU    1332
# b0046      47245    47776      +      kefF     531
# b0047      47768    49631      +      kefC    1863
# b0048      49822    50302      +      folA     480
# b0049      50379    51222      -      apaH     843
# b0050      51228    51606      -      apaG     378
# b0051      51608    52430      -      rsmA     822
# b0052      52426    53416      -      pdxA     990
# b0053      53415    54702      -      surA    1287
# b0054      54754    57109      -      lptD    2355
# b0055      57363    58179      +      djlA     816
# b4659_1    58473    59052      +    yabP_1     579
# b4659_2    59051    59279      +    yabP_2     228
# b0058      59686    60346      -      rluA     660
# b0059      60357    63264      -      rapA    2907
# b0060      63428    65780      -      polB    2352
# b0061      65854    66550      -      araD     696
# b0062      66834    68337      -      araA    1503
# b0063      68347    70048      -      araB    1701
# b0064      70386    71265      +      araC     879
# b0065      71350    72115      +      yabI     765
# b0066      72228    72927      -      thiQ     699
# b0067      72910    74521      -      thiP    1611
# b0068      74496    75480      -      thiB     984
# b0069      75643    77299      -      sgrR    1656
# b4662      77387    77519      +      sgrT     132
# b0070      77620    78799      +      setA    1179
# b0071      78847    79453      -      leuD     606
# b0072      79463    80864      -      leuC    1401
# b0073      80866    81958      -      leuB    1092
# b0074      81957    83529      -      leuA    1572
# b0075      83621    83708      -      leuL      87
# b0076      84367    85312      +      leuO     945
# b0077      85629    87354      +      ilvI    1725
# b0078      87356    87848      +      ilvH     492
# b0080      88027    89032      +       cra    1005
# b0081      89633    90092      +      mraZ     459
# b0082      90093    91035      +      rsmH     942
# b0083      91031    91397      +      ftsL     366
# b0084      91412    93179      +      ftsI    1767
# b0085      93165    94653      +      murE    1488
# b0086      94649    96008      +      murF    1359
# b0087      96001    97084      +      mraY    1083
# b0088      97086    98403      +      murD    1317
# b0089      98402    99647      +      ftsW    1245
# b0090      99643   100711      +      murG    1068
# b0091     100764   102240      +      murC    1476
# b0092     102232   103153      +      ddlB     921
# b0093     103154   103985      +      ftsQ     831
# b0094     103981   105244      +      ftsA    1263
# b0095     105304   106456      +      ftsZ    1152
# b0096     106556   107474      +      lpxC     918
# b0097     107704   108217      +      secM     513
# b0098     108278   110984      +      secA    2706
# b0099     111043   111433      +      mutT     390
# b0101     111648   111846      -      yacG     198
# b0102     111855   112599      -      zapD     744
# b0103     112598   113219      -      coaE     621
# b0104     113443   114487      +      guaC    1044
# b0106     114521   115724      -      hofC    1203
# b0107     115713   117099      -      hofB    1386
# b0108     117108   117549      -      ppdD     441
# b0109     117751   118645      -      nadC     894
# b0110     118732   119284      +      ampD     552
# b0111     119280   120135      +      ampE     855
# b0112     120177   121551      -      aroP    1374
# b0113     122091   122856      +      pdhR     765
# b0114     123016   125680      +      aceE    2664
# b0115     125694   127587      +      aceF    1893
# b0116     127911   129336      +       lpd    1425
# b0117     129406   131260      -      yacH    1854
# b0118     131614   134212      +      acnB    2598
# b0119     134387   134750      +      yacL     363
# b0120     134787   135582      -      speD     795
# b0121     135597   136464      -      speE     867
# b0122     136569   136917      -      yacC     348
# b0123     137082   138633      +      cueO    1551
# b0124     138834   141225      -       gcd    2391
# b0125     141430   141967      +       hpt     537
# b0126     142007   142670      -       can     663
# b0127     142778   143705      +      yadG     927
# b0128     143701   144472      +      yadH     771
# b0129     144576   145017      +      yadI     441
# b0130     145080   146310      +      yadE    1230
# b0131     146313   146694      -      panD     381
# b0132     146967   147870      +      yadD     903
# b0133     147943   148795      -      panC     852
# b0134     148806   149601      -      panB     795
# b0135     149714   150953      -      yadC    1239
# b0136     151002   151599      -      yadK     597
# b0137     151625   152231      -      yadL     606
# b0138     152242   152812      -      yadM     570
# b0139     152828   155426      -      htrE    2598
# b0140     155460   156201      -      yadV     741
# b0141     156298   156883      -      yadN     585
# b0142     157252   157732      -      folK     480
# b0143     157728   159126      -      pcnB    1398
# b0144     159185   160112      -      gluQ     927
# b0145     160148   160604      -      dksA     456
# b0146     160781   161486      -      sfsA     705
# b0147     161500   162031      -      ligT     531
# b0148     162104   164534      +      hrpB    2430
# b0149     164729   167264      +      mrcB    2535
# b0150     167483   169727      +      fhuA    2244
# b0151     169777   170575      +      fhuC     798
# b0152     170574   171465      +      fhuD     891
# b0153     171461   173444      +      fhuB    1983
# b0154     173601   174882      -      hemL    1281
# b0155     175106   176528      +      clcA    1422
# b0156     176609   176954      +      erpA     345
# b0157     177000   177624      -      yadS     624
# b0158     177661   178462      -      btuF     801
# b0159     178454   179153      -       mtn     699
# b0160     179236   180754      +       dgt    1518
# b0161     180883   182308      +      degP    1425
# b0162     182462   183620      +      cdaR    1158
# b0163     183708   184095      -      yaeH     387
# b0164     184256   185069      -      yaeI     813
# b0166     185122   185947      -      dapD     825
# b0167     185977   188650      -      glnD    2673
# b0168     188711   189506      -       map     795
# b0169     189873   190599      +      rpsB     726
# b0170     190856   191708      +       tsf     852
# b0171     191854   192580      +      pyrH     726
# b0172     192871   193429      +       frr     558
# b0173     193520   194717      +       dxr    1197
# b0174     194902   195664      +      ispU     762
# b0175     195676   196534      +      cdsA     858
# b0176     196545   197898      +      rseP    1353
# b0177     197927   200360      +      bamA    2433
# b0178     200481   200967      +       skp     486
# b0179     200970   201996      +      lpxD    1026
# b0180     202100   202556      +      fabZ     456
# b0181     202559   203348      +      lpxA     789
# b0182     203347   204496      +      lpxB    1149
# b0183     204492   205089      +      rnhB     597
# b0184     205125   208608      +      dnaE    3483
# b0185     208620   209580      +      accA     960
# b0186     209678   211820      +      ldcC    2142
# b0187     211876   212266      +      yaeR     390
# b0188     212330   213629      +      tilS    1299
# b0189     213677   213932      -       rof     255
# b4406     213924   214125      -      yaeP     201
# b0190     214290   214836      +      yaeQ     546
# b0191     214832   215255      +      arfB     423
# b0192     215268   215979      +      nlpE     711
# b0193     216178   217003      -      yaeF     825
# b0194     217056   218775      -      proS    1719
# b0195     218886   219594      -      tsaA     708
# b0196     219590   219995      -      rcsF     405
# b0197     220112   220928      -      metQ     816
# b0198     220967   221621      -      metI     654
# b0199     221613   222645      -      metN    1032
# b0200     222832   223408      +      gmhB     576
# b0207     229166   229970      +      dkgB     804
# b0208     229966   230881      -      yafC     915
# b0209     231121   231922      +      yafD     801
# b0210     231925   232549      +      yafE     624
# b0211     232596   233955      -      mltD    1359
# b0212     234026   234782      -      gloB     756
# b0213     234815   235538      +      yafS     723
# b0214     235534   236002      -      rnhA     468
# b0215     236066   236798      +      dnaQ     732
# b0217     237334   238120      +      yafT     786
# b4586     238256   238736      -      ykfM     480
# b0218     238745   239102      -      yafU     357
# b4503     239105   239378      +      yafF     273
# b0219     239418   240189      -      yafV     771
# b0220     240342   240816      +       ivy     474
# b0221     240858   243303      -      fadE    2445
# b0222     243542   244121      +      gmhA     579
# b0223     244326   245094      +      yafJ     768
# b0224     245064   245805      -      yafK     741
# b0225     245960   246239      -      yafQ     279
# b0226     246241   246502      -      dinJ     261
# b0227     246711   247461      +      yafL     750
# b0228     247636   248134      +      rayT     498
# b0229     248357   250070      -      lfhA    1713
# b0230     250071   250827      +      lafU     756
# b0231     250897   251953      +      dinB    1056
# b0232     252004   252298      +      yafN     294
# b0233     252300   252699      +      yafO     399
# b0234     252708   253161      +      yafP     453
# b0235     253478   253685      +      ykfJ     207
# b0236     253701   254202      +      prfH     501
# b0237     254258   255716      -      pepD    1458
# b0238     255976   256435      +       gpt     459
# b0239     256526   257771      +      frsA    1245
# b0240_1   257828   257899      +     crl_1      71
# b0240_2   258675   259006      +     crl_2     331
# b0241     259044   260100      -      phoE    1056
# b0242     260387   261491      +      proB    1104
# b0243     261502   262756      +      proA    1254
# b4626     263149   263212      -      ykfN      63
# b0245     263327   263669      -      ykfI     342
# b0246     263689   264007      -      yafW     318
# b4504     264025   264247      -      ykfH     222
# b0247     264255   264732      -      ykfG     477
# b0248     264747   265206      -      yafX     459
# b0249     265303   265543      -      ykfF     240
# b0250     265619   266087      -      ykfB     468
# b0251     266109   266553      -      yafY     444
# b4627     266552   266774      -      ykfL     222
# b4628     266775   266967      -      ykfK     192
# b0252     267183   268005      -      yafZ     822
# b0253     268096   268960      -      ykfA     864
# b0254     269288   270182      -      perR     894
# b4587_1   270277   270535      +    insN_1     258
# b0256     270602   271754      +     insI1    1152
# b4587_2   271763   272189      +    insN_2     426
# b0258     272846   273954      +      ykfC    1108
# b0259     274100   275117      -     insH1    1017
# b0260     275324   276728      +      mmuP    1404
# b0261     276714   277647      +      mmuM     933
# b0262     277755   278802      -      afuC    1047
# b0263     278813   279161      -      afuB     348
# b0264     279177   279681      -     insB1     504
# b0265     279599   279875      -      insA     276
# b4708     279930   280104      +     insI1     174
# b4505     280113   280362      -      insX     249
# b0266     280426   280735      -      yagB     309
# b0267     280828   281983      -      yagA    1155
# b0268     282277   283186      +      yagE     909
# b0269     283200   285168      +      yagF    1968
# b0270     285394   286777      +      yagG    1383
# b0271     286788   288399      +      yagH    1611
# b0272     288403   289162      -      yagI     759
# b0273     289300   290305      -      argF    1005
# b4688     290428   290633      +      ykgS     205
# b0274     290648   291152      -     insB1     504
# b0275     291070   291346      -      insA     276
# b0276     291403   292231      +      yagJ     828
# b0277     292321   292948      -      yagK     627
# b0278     293219   293918      -      yagL     699
# b0279     293944   294799      -      yagM     855
# b0280     295138   295579      -      yagN     441
# b0281     295695   297096      -      intF    1401
# b4694     297380   297719      -      yagP     339
# b4695     297713   297791      -      ykgT      78
# b0283     297769   298726      -      paoD     957
# b0284     298735   300934      -      paoC    2199
# b0285     300930   301887      -      paoB     957
# b0286     301883   302573      -      paoA     690
# b0287     302990   303605      +      yagU     615
# b0288     303852   304182      -      ykgJ     330
# b0289     304494   305205      -      ecpE     711
# b0290     305173   306817      -      ecpD    1644
# b0291     306806   309332      -      ecpC    2526
# b0292     309357   310026      -      ecpB     669
# b0293     310083   310671      -      ecpA     588
# b0294     310745   311336      -      ecpR     591
# b0295     312111   312339      +      ykgL     228
# b4506     312373   312514      -      ykgO     141
# b0296     312513   312777      -      ykgM     264
# b4671     313140   313242      -      ykgR     102
# b4630     313715   313805      -      ykgP      90
# b0297     314356   315228      +      eaeH     872
# b0298     315290   315590      +     insE1     300
# b0299     315586   316453      +     insF1     867
# b0300     316485   317169      -      ykgA     684
# b4631     317438   317567      +      ykgQ     129
# b0301     317725   318319      -      rclC     594
# b0303     318330   318567      -      rclB     237
# b0304     318675   320001      -      rclA    1326
# b0305     320226   321081      +      rclR     855
# b0306     321607   322327      +      ykgE     720
# b0307     322337   323765      +      ykgF    1428
# b0308     323757   324453      +      ykgG     696
# b0310     324695   325364      -      ykgH     669
# b0311     325576   327247      -      betA    1671
# b0312     327260   328733      -      betB    1473
# b0313     328746   329334      -      betI     588
# b0314     329462   331496      +      betT    2034
# b0315     332370   333459      +      yahA    1089
# b0316     333500   334433      -      yahB     933
# b0317     334524   335022      -      yahC     498
# b0318     335279   335885      +      yahD     606
# b0319     335924   336788      +      yahE     864
# b0320     336777   338325      +      yahF    1548
# b0321     338324   339743      +      yahG    1419
# b0323     340164   341115      +      yahI     951
# b0324     341124   342507      +      yahJ    1383
# b0325     342883   343933      +      yahK    1050
# b0326     344175   344991      +      yahL     816
# b0327     345403   345649      +      yahM     246
# b0328     345665   346337      -      yahN     672
# b0329     346483   346759      +      yahO     276
# b0330     346856   348443      -      prpR    1587
# b0331     348681   349572      +      prpB     891
# b0333     350011   351181      +      prpC    1170
# b0334     351214   352666      +      prpD    1452
# b0335     352705   354592      +      prpE    1887
# b0336     354921   356181      +      codB    1260
# b0337     356170   357454      +      codA    1284
# b0338     357790   358690      -      cynR     900
# b0339     358798   359458      +      cynT     660
# b0340     359488   359959      +      cynS     471
# b0341     359991   361146      +      cynX    1155
# b0342     361248   361860      -      lacA     612
# b0343     361925   363179      -      lacY    1254
# b0344     363230   366305      -      lacZ    3075
# b0345     366427   367510      -      lacI    1083
# b0346     367586   368420      -      mhpR     834
# b0347     368610   370275      +      mhpA    1665
# b0348     370276   371221      +      mhpB     945
# b0349     371238   372105      +      mhpC     867
# b0350     372114   372924      +      mhpD     810
# b0351     372920   373871      +      mhpF     951
# b0352     373867   374881      +      mhpE    1014
# b0353     375458   376670      +      mhpT    1212
# b0354     376771   377311      +      yaiL     540
# b0355     377534   378368      -      frmB     834
# b0356     378461   379571      -      frmA    1110
# b0357     379605   379881      -      frmR     276
# b0358     380068   380842      -      yaiO     774
# b4579_2   380843   381260      -    yaiX_2     417
# b0360     381350   381716      +     insC1     366
# b0361     381673   382579      +     insD1     906
# b4579_1   382590   382872      -    yaiX_1     282
# b0363     382738   383935      -      yaiP    1197
# b0364     384058   384616      -      yaiS     558
# b0365     385231   386194      +      tauA     963
# b0366     386206   386974      +      tauB     768
# b0367     386970   387798      +      tauC     828
# b0368     387794   388646      +      tauD     852
# b0369     388752   389727      -      hemB     975
# b4580_1   390250   391708      +    yaiT_1    1458
# b0372     391738   392605      -     insF1     867
# b0373     392601   392901      -     insE1     300
# b4580_2   392969   394418      +    yaiT_2    1449
# b0375     394505   395129      +      yaiV     624
# b0376     395129   396287      -      ampH    1158
# b0377     396638   397859      +      sbmA    1221
# b0378     397871   398966      +      yaiW    1095
# b0379     399024   399333      -      yaiY     309
# b0380     399592   399805      +      yaiZ     213
# b0381     399828   400923      -      ddlA    1095
# b0382     401385   401646      +      iraP     261
# b0383     401746   403162      +      phoA    1416
# b0384     403280   403601      +      psiF     321
# b0385     403702   404818      +      yaiC    1116
# b0386     404834   405644      -      proC     810
# b0387     405763   406222      +      yaiI     459
# b0388     406404   406929      +      aroL     525
# b0389     406978   407170      +      yaiA     192
# b0390     407427   408105      +      aroM     678
# b0391     408176   408461      +      yaiE     285
# b0392     408608   408950      +      ykiA     342
# b0393     409107   410019      -      rdgC     912
# b0394     410143   411052      +       mak     909
# b0396     411296   412481      -      araJ    1185
# b0397     412606   415753      -      sbcC    3147
# b0398     415749   416952      -      sbcD    1203
# b0399     417141   417831      +      phoB     690
# b0400     417888   419184      +      phoR    1296
# b0401     419590   420910      +      brnQ    1320
# b0402     420985   422359      +      proY    1374
# b0403     422517   424332      +      malZ    1815
# b0404     424336   424918      -      acpH     582
# b0405     425010   426081      +      queA    1071
# b0406     426136   427264      +       tgt    1128
# b0407     427286   427619      +      yajC     333
# b0408     427646   429494      +      secD    1848
# b0409     429504   430476      +      secF     972
# b0410     430604   430952      +      yajD     348
# b0411     431128   432013      -       tsx     885
# b0412     432311   432851      -      yajI     540
# b0413     433001   433451      +      nrdR     450
# b0414     433454   434558      +      ribD    1104
# b0415     434646   435117      +      ribE     471
# b0416     435136   435556      +      nusB     420
# b0417     435633   436611      +      thiL     978
# b0418     436588   437107      +      pgpA     519
# b0419     437160   438135      -      yajO     975
# b0420     438314   440177      -       dxs    1863
# b0421     440201   441101      -      ispA     900
# b0422     441100   441343      -      xseB     243
# b0423     441548   442997      +      thiI    1449
# b0424     443050   443641      -      yajL     591
# b0425     443603   444515      -      panE     912
# b0426     444682   445174      +      yajQ     492
# b0427     445301   446666      -      yajR    1365
# b0428     446814   447705      -      cyoE     891
# b0429     447716   448046      -      cyoD     330
# b0430     448045   448660      -      cyoC     615
# b0431     448649   450641      -      cyoB    1992
# b0432     450662   451610      -      cyoA     948
# b0433     452069   453545      -      ampG    1476
# b0434     453588   454167      -      yajG     579
# b0435     454471   454789      +      bolA     318
# b0436     455132   456431      +       tig    1299
# b0437     456676   457300      +      clpP     624
# b0438     457425   458700      +      clpX    1275
# b0439     458887   461242      +       lon    2355
# b0440     461450   461723      +      hupB     273
# b0441     461914   463786      +      ppiD    1872
# b0442     463936   464308      +      ybaV     372
# b0443     464401   464800      +      fadM     399
# b0444     464851   465547      -      queC     696
# b0445     465611   467312      -      ybaE    1701
# b0446     467411   468230      +       cof     819
# b0447     468382   468841      +      ybaO     459
# b0448     468870   470643      +      mdlA    1773
# b0449     470635   472417      +      mdlB    1782
# b0450     472597   472936      +      glnK     339
# b0451     472965   474252      +      amtB    1287
# b0452     474300   475161      -      tesB     861
# b0453     475378   475951      +      ybaY     573
# b0454     475981   476371      -      ybaZ     390
# b0456     476671   477025      +      ybaA     354
# b0457     477066   478617      -      ylaB    1551
# b0458     478780   479251      -      ylaC     471
# b0459     479366   479918      -       maa     552
# b0460     480089   480308      -       hha     219
# b0461     480333   480708      -      tomB     375
# b0462     481253   484403      -      acrB    3150
# b0463     484425   485619      -      acrA    1194
# b0464     485760   486408      +      acrR     648
# b0465     486535   489898      +      mscK    3363
# b0466     490109   490271      -      ybaM     162
# b0467     490284   490812      -      priC     528
# b0468     490881   491259      +      ybaN     378
# b0469     491411   491963      +       apt     552
# b0470     492091   494023      +      dnaX    1932
# b0471     494075   494405      +      ybaB     330
# b0472     494404   495010      +      recR     606
# b0473     495119   496994      +      htpG    1875
# b0474     497174   497819      +       adk     645
# b0475     498054   499017      +      hemH     963
# b0476     499013   499973      -       aes     960
# b0477     500124   501429      +       gsk    1305
# b0478     501561   503238      -      ybaL    1677
# b0479     503475   504696      -       fsr    1221
# b0480     504913   506566      +      ushA    1653
# b0481     506602   507082      -      ybaK     480
# b0482     507285   508080      -      ybaP     795
# b0483     508217   508559      +      ybaQ     342
# b0484     508874   511379      -      copA    2505
# b0485     511640   512573      +      glsA     933
# b0486     512575   513868      +      ybaT    1293
# b0487     513992   514400      +      cueR     408
# b0488     514400   514859      -      ybbJ     459
# b0489     514855   515773      -      qmcA     918
# b0490     515918   516596      +      fetA     678
# b0491     516582   517362      +      fetB     780
# b0492     517424   518279      -      ybbN     855
# b0493     518339   519149      -      ybbO     810
# b0494     519138   519765      -      tesA     627
# b0495     519732   520419      +      ybbA     687
# b0496     520415   522830      +      ybbP    2415
# b0497     523260   527541      +      rhsD    4281
# b0498     527580   527949      +      ybbC     369
# b0499     527951   528659      +      rhsH     708
# b0501     528639   529130      +      ybbD     491
# b4632     529499   529592      +      ylbI      93
# b0502_2   529594   529660      -    ylbG_2      66
# b0502_1   529659   530016      -    ylbG_1     357
# b0503     530131   531226      -      mnmH    1095
# b0504     531294   532221      -      allS     927
# b0505     532450   532933      +      allA     483
# b0506     533010   533826      +      allR     816
# b0507     533915   535697      +       gcl    1782
# b0508     535709   536486      +       hyi     777
# b0509     536585   537464      +      glxR     879
# b0511     537632   539087      +      ybbW    1455
# b0512     539146   540508      +      allB    1362
# b0513     540564   541866      +      ybbY    1302
# b0514     541887   543033      +      glxK    1146
# b0515     543260   544046      -      allE     786
# b0516     544056   545292      -      allC    1236
# b0517     545313   546363      -      allD    1050
# b0518     546679   548347      +      fdrA    1668
# b4572     548356   549616      +      ylbE    1260
# b0520     549626   550442      +      ylbF     816
# b0521     550438   551332      +      ybcF     894
# b0522     551526   552594      -      purK    1068
# b0523     552590   553100      -      purE     510
# b0524     553217   553940      -      lpxH     723
# b0525     553942   554437      -      ppiB     495
# b0526     554610   555996      +      cysS    1386
# b0527     556031   556553      -      ybcI     522
# b0528     556660   556873      -      ybcJ     213
# b0529     556874   557741      -      folD     867
# b0530     558211   558754      +      sfmA     543
# b0531     558973   559666      +      sfmC     693
# b0532     559696   562300      +      sfmD    2604
# b0533     562335   563319      +      sfmH     984
# b0534     563329   563845      +      sfmF     516
# b0535     563847   564480      -      sfmZ     633
# b0537     564814   565978      -      intD    1164
# b4633     565857   566079      -      xisD     222
# b0539     566097   566376      -      exoD     279
# b4508     566375   566687      +      peaD     312
# b0542_1   566683   566776      +    renD_1      93
# b0540     566841   567141      +     insE1     300
# b0541     567137   568004      +     insF1     867
# b0542_2   568034   568247      +    renD_2     213
# b0543     568314   568647      +      emrE     333
# b0544     568901   570428      +      ybcK    1527
# b0545     570892   571444      +      ybcL     552
# b0546     571453   572251      +      ybcM     798
# b4588     572367   572469      +      ylcH     102
# b0547     572465   572921      +      ybcN     456
# b0548     572920   573091      +      ninE     171
# b0549     573083   573374      +      ybcO     291
# b0550     573370   573733      +      rusA     363
# b4509     573729   573870      +      ylcG     141
# b0551     573955   574339      +      quuD     384
# b0553_2   574528   574586      -    nmpC_2      58
# b0552     574736   575753      -     insH1    1017
# b0553_1   575785   576825      -    nmpC_1    1040
# b0554     577397   577613      +      essD     216
# b0555     577612   578110      +      rrrD     498
# b0556     578106   578568      +      rzpD     462
# b4510     578326   578509      +      rzoD     183
# b0557     578599   578893      -      borD     294
# b0558     579183   579594      -      ybcV     411
# b0559     579879   580086      +      ybcW     207
# b4589     580250   580445      -      ylcI     195
# b0560     580833   581379      +      nohD     546
# b4634     581353   581662      +      aaaD     309
# b0561     581659   582097      +      tfaD     438
# b0562_2   582151   582804      -    ybcY_2     653
# b0562_1   582802   582806      -    ybcY_1       4
# b0563     582952   583135      +      tfaX     183
# b0564     583680   584430      +      appY     750
# b0565     584679   585633      -      ompT     954
# b0566     586146   586908      -      envY     762
# b0567     587090   587981      -      ybcH     891
# b0568     587981   590954      -      nfrA    2973
# b0569     590940   593178      -      nfrB    2238
# b0570     593327   594770      -      cusS    1443
# b0571     594759   595443      -      cusR     684
# b0572     595599   596973      +      cusC    1374
# b0573     597130   597463      +      cusF     333
# b0574     597478   598702      +      cusB    1224
# b0575     598713   601857      +      cusA    3144
# b0576     601958   603335      +      pheP    1377
# b0577     603415   604663      -      ybdG    1248
# b0578     604770   605424      -      nfsB     654
# b0579     605517   605886      -      ybdF     369
# b0580     605950   606199      -      ybdJ     249
# b0581     606264   607383      -      ybdK    1119
# b4415     607835   607988      +      hokE     153
# b0582     608064   609177      +     insL1    1113
# b0583     609458   610079      -      entD     621
# b0584     610253   612494      -      fepA    2241
# b0585     612736   613939      +       fes    1203
# b4511     613941   614160      +      ybdZ     219
# b0586     614156   618038      +      entF    3882
# b0587     618253   619387      +      fepE    1134
# b0588     619383   620199      -      fepC     816
# b0589     620195   621188      -      fepG     993
# b0590     621184   622189      -      fepD    1005
# b0591     622299   623550      +      entS    1251
# b0592     623553   624510      -      fepB     957
# b0593     624884   626060      +      entC    1176
# b0594     626069   627680      +      entE    1611
# b0595     627693   628551      +      entB     858
# b0596     628550   629297      +      entA     747
# b0597     629299   629713      +      entH     414
# b0598     629893   631999      +      cstA    2106
# b4512     632181   632379      +      ybdD     198
# b0599     632388   633477      -      ybdH    1089
# b0600     633585   634746      +      ybdL    1161
# b0601     634746   635376      -      ybdM     630
# b0602     635348   636569      -      ybdN    1221
# b0603     636715   637618      -      ybdO     903
# b0604     637826   638573      -      dsbG     747
# b0605     638944   639508      +      ahpC     564
# b0606     639752   641318      +      ahpF    1566
# b0607     641438   641867      -      uspG     429
# b0608     642087   643326      +      ybdR    1239
# b0610     643556   643967      -       rnk     411
# b0611     644196   645003      -       rna     807
# b0612     645116   646580      -      citT    1464
# b0613     646630   647509      -      citG     879
# b0614     647483   648035      -      citX     552
# b0615     648038   649571      -      citF    1533
# b0616     649581   650490      -      citE     909
# b0617     650486   650783      -      citD     297
# b0618     650797   651856      -      citC    1059
# b0619     652234   653893      +      citA    1659
# b0620     653861   654542      +      citB     681
# b0621     654582   655968      -      dcuC    1386
# b0622     656556   657117      +      pagP     561
# b0623     657291   657501      +      cspE     210
# b0624     657554   657938      -       flc     384
# b4581_1   658030   658225      +    ybeM_1     195
# b4581_2   658224   658818      +    ybeM_2     594
# b0627     658946   659150      +      tatE     204
# b0628     659250   660216      -      lipA     966
# b0629     660424   661378      -      ybeF     954
# b0630     661636   662278      -      lipB     642
# b0631     662378   662642      -      ybeD     264
# b0632     662751   663963      -      dacA    1212
# b0633     664101   665190      -      rlpA    1089
# b0634     665200   666313      -      mrdB    1113
# b0635     666315   668217      -      mrdA    1902
# b0636     668247   668715      -      rlmH     468
# b0637     668718   669036      -      rsfS     318
# b0638     669295   669907      -      cobC     612
# b0639     669930   670572      -      nadD     642
# b0640     670573   671605      -      holA    1032
# b0641     671604   672186      -      lptE     582
# b0642     672200   674783      -      leuS    2583
# b0643     675017   675500      +      ybeL     483
# b0644     675569   676547      -      ybeQ     978
# b0645     676710   677418      +      ybeR     708
# b0646     677414   678842      +      djlB    1428
# b0647     678851   679406      -      ybeT     555
# b0648     679507   680215      +      ybeU     708
# b0649     680211   681663      +      djlC    1452
# b0650     681722   683393      -      hscC    1671
# b0651     683476   684412      -      rihA     936
# b0652     684529   685255      -      gltL     726
# b0653     685254   685929      -      gltK     675
# b0654     685928   686669      -      gltJ     741
# b0655     686838   687747      -      gltI     909
# b0656     687996   689013      -     insH1    1017
# b0657     689342   690881      -       lnt    1539
# b0658     690905   691784      -      ybeX     879
# b0659     691873   692341      -      ybeY     468
# b0660     692337   693378      -      ybeZ    1041
# b0661     693530   694955      -      miaB    1425
# b0662     695100   696276      +      ubiF    1176
# b0674     697512   699177      -      asnB    1665
# b0675     699573   700326      -      umpH     753
# b0676     700373   701594      -      nagC    1221
# b0677     701602   702751      -      nagA    1149
# b0678     702810   703611      -      nagB     801
# b0679     703943   705890      +      nagE    1947
# b0680     706092   707757      +      glnS    1665
# b0681     708333   709740      +      chiP    1407
# b0682     709789   710116      +      chiQ     327
# b0683     710199   710646      -       fur     447
# b4637     710638   710725      -       uof      87
# b0684     710934   711465      -      fldA     531
# b0685     711604   711898      -      ybfE     294
# b0686     712037   712802      -      ybfF     765
# b0687     712986   713532      +      seqA     546
# b0688     713557   715198      +       pgm    1641
# b0689     715411   715906      +      ybfP     495
# b0691     715946   716597      -      ybfG     651
# b4636     716720   716870      -      ybfI     150
# b0692     716945   718265      -      potE    1320
# b0693     718261   720460      -      speF    2199
# b4590     720582   720840      +      ybfK     258
# b0694     721055   721733      -      kdpE     678
# b0695     721729   724414      -      kdpD    2685
# b0696     724406   724979      -      kdpC     573
# b0697     724987   727036      -      kdpB    2049
# b0698     727058   728732      -      kdpA    1674
# b4513     728731   728821      -      kdpF      90
# b0699     729133   729340      +      ybfA     207
# b0700     729582   733776      +      rhsC    4194
# b0702     733775   734102      +      ybfB     327
# b0703     734132   735653      +      rhsO    1521
# b0704     735649   736219      +      ybfC     570
# b4514     736444   736684      +      ybfQ     240
# b0705     736824   737961      +      ybfL    1137
# b0706     738091   738853      +      ybfD     762
# b0707     739000   739510      +      ybgA     510
# b0708     739506   740925      +       phr    1419
# b0709     741074   742556      -      dtpD    1482
# b0710     742826   743570      +      ybgI     744
# b0711     743592   744249      +      ybgJ     657
# b0712     744242   745175      +      ybgK     933
# b0713     745164   745899      +      ybgL     735
# b0714     745934   746726      +       nei     792
# b0715     746722   747769      -      abrB    1047
# b0716     747920   748982      -      ybgO    1062
# b0717     748978   749707      -      ybgP     729
# b0718     749721   752169      -      ybgQ    2448
# b0719     752228   752795      -      ybgD     567
# b0720     753184   754468      -      gltA    1284
# b0721     755176   755566      +      sdhC     390
# b0722     755559   755907      +      sdhD     348
# b0723     755906   757673      +      sdhA    1767
# b0724     757688   758405      +      sdhB     717
# b0726     758705   761507      +      sucA    2802
# b0727     761521   762739      +      sucB    1218
# b0728     763013   764180      +      sucC    1167
# b0729     764179   765049      +      sucD     870
# b0730     765152   765875      -      mngR     723
# b0731     765983   767960      +      mngA    1977
# b0732     767977   770611      +      mngB    2634
# b0733     771457   773026      +      cydA    1569
# b0734     773041   774181      +      cydB    1140
# b4515     774195   774309      +      cydX     114
# b0735     774308   774602      +      ybgE     294
# b0736     774751   775156      +      ybgC     405
# b0737     775152   775845      +      tolQ     693
# b0738     775848   776277      +      tolR     429
# b0739     776341   777607      +      tolA    1266
# b0740     777739   779032      +      tolB    1293
# b0741     779066   779588      +       pal     522
# b0742     779597   780389      +      ybgF     792
# b0750     782084   783128      +      nadA    1044
# b0751     783165   783885      +      pnuC     720
# b0752     783881   784823      -      zitB     942
# b0753     784936   785317      -      ybgS     381
# b0754     785632   786685      +      aroG    1053
# b0755     786842   787595      -      gpmA     753
# b0756     787796   788837      -      galM    1041
# b0757     788830   789979      -      galK    1149
# b0758     789982   791029      -      galT    1047
# b0759     791038   792055      -      galE    1017
# b0760     792315   793788      -      modF    1473
# b0761     793855   794644      -      modE     789
# b0762     794772   794922      +      acrZ     150
# b0763     795088   795862      +      modA     774
# b0764     795861   796551      +      modB     690
# b0765     796553   797612      +      modC    1059
# b0766     797612   798431      -      ybhA     819
# b0767     798585   799581      +       pgl     996
# b0768     799621   800575      -      ybhD     954
# b0769     800758   801811      +      ybhH    1053
# b0770     801886   803320      +      ybhI    1434
# b0771     803502   805764      +      ybhJ    2262
# b0772     805997   807281      -      ybhC    1284
# b0773     807432   807909      -      ybhB     477
# b0774     807967   809257      -      bioA    1290
# b0775     809343   810384      +      bioB    1041
# b0776     810380   811535      +      bioF    1155
# b0777     811521   812277      +      bioC     756
# b0778     812269   812947      +      bioD     678
# b0779     813525   815547      +      uvrB    2022
# b0780     815738   816647      -      ybhK     909
# b0781     817043   818033      +      moaA     990
# b0782     818054   818567      +      moaB     513
# b0783     818569   819055      +      moaC     486
# b0784     819047   819293      +      moaD     246
# b0785     819294   819747      +      moaE     453
# b0786     819883   820588      +      ybhL     705
# b0787     820792   821506      +      ybhM     714
# b0788     821541   822498      -      ybhN     957
# b0789     822497   823739      -      clsB    1242
# b0790     823735   824497      -      ybhP     762
# b0791     824629   825040      +      ybhQ     411
# b0792     825001   826108      -      ybhR    1107
# b0793     826118   827252      -      ybhS    1134
# b0794     827244   828981      -      ybhF    1737
# b0795     828973   829972      -      ybhG     999
# b0796     829971   830643      -      ybiH     672
# b0797     830871   832236      +      rhlE    1365
# b0798     832467   832950      -      ybiA     483
# b0799     833069   835220      +      dinG    2151
# b0800     835247   836210      +      ybiB     963
# b0801     836350   837436      +      ybiC    1086
# b0802     837664   837925      -      ybiJ     261
# b0803     838189   838456      -      ybiI     267
# b0804     838529   839207      -      ybiX     678
# b0805     839248   841531      -       fiu    2283
# b0806     841795   842056      -      mcbA     261
# b0807     842331   843258      +      rlmF     927
# b0808     843254   845480      -      ybiO    2226
# b0809     845740   846463      -      glnQ     723
# b0810     846459   847119      -      glnP     660
# b0811     847257   848004      -      glnH     747
# b0812     848407   848911      -       dps     504
# b0813     849209   850097      -      rhtA     888
# b0814     850449   850965      +      ompX     516
# b0815     851013   852597      -      opgE    1584
# b4705     852868   852997      -      mntS     129
# b0817     853182   853650      +      mntR     468
# b0818     853646   854765      +      ybiR    1119
# b0819     854823   855744      -      ldtB     921
# b0820     855962   857555      +      ybiT    1593
# b0821     857795   859061      -      ybiU    1266
# b0822     859212   860028      -      ybiV     816
# b0823     860173   862606      -      ybiW    2433
# b0824     862611   863511      -      ybiY     900
# b0825     863641   864304      +      fsaA     663
# b0826     864379   865129      -      moeB     750
# b0827     865128   866364      -      moeA    1236
# b0828     866567   867533      +      iaaA     966
# b0829     867519   869391      +      gsiA    1872
# b0830     869410   870949      +      gsiB    1539
# b0831     870966   871887      +      gsiC     921
# b0832     871889   872801      +      gsiD     912
# b0833     872978   875327      +      yliE    2349
# b0834     875334   876663      +      yliF    1329
# b0835     876709   878035      -      rimO    1326
# b0836     878247   878631      +      bssR     384
# b0837     878741   879857      +      yliI    1116
# b0838     879853   880480      -      gstB     627
# b0839     880726   881929      +      dacC    1203
# b0840     881975   882734      -      deoR     759
# b0841     882791   883388      -      ybjG     597
# b0842     883672   884905      +      mdfA    1233
# b0843     884945   885230      -      ybjH     285
# b0844     885315   886131      -      ybjI     816
# b0845     886130   887339      -      ybjJ    1209
# b0846     887422   887959      +      rcdA     537
# b0847     888133   889819      -      ybjL    1686
# b0848     890088   890466      +      ybjM     378
# b0849     890495   890753      -      grxA     258
# b0850     890912   891200      +      ybjC     288
# b0851     891183   891906      +      nfsA     723
# b0852     891966   892869      +      rimK     903
# b0853     892956   893433      +      ybjN     477
# b0854     893783   894896      +      potF    1113
# b0855     894990   896124      +      potG    1134
# b0856     896133   897087      +      potH     954
# b0857     897083   897929      +      potI     846
# b0858     897988   898477      +      ybjO     489
# b0859     898517   899645      +      rlmC    1128
# b0860     899843   900575      -      artJ     732
# b0861     900865   901534      -      artM     669
# b0862     901533   902250      -      artQ     717
# b0863     902256   902988      -      artI     732
# b0864     903005   903734      -      artP     729
# b0865     903951   904467      -      ybjP     516
# b0866     904592   904916      +      ybjQ     324
# b0867     904912   905743      +      amiD     831
# b0868     905739   906753      -      ybjS    1014
# b0869     906851   908282      -      ybjT    1431
# b0870     908292   909294      -      ltaE    1002
# b0871     909330   911049      -      poxB    1719
# b0872     911181   912150      -       hcr     969
# b0873     912161   913814      -       hcp    1653
# b0874     913957   914857      -      ybjE     900
# b0875     915351   916047      -      aqpZ     696
# b0876     916472   918131      +      ybjD    1659
# b0877     918127   919120      -      ybjX     993
# b0878     919234   920350      +      macA    1116
# b0879     920346   922293      +      macB    1947
# b0880     922365   922590      -      cspD     225
# b0881     922912   923233      +      clpS     321
# b0882     923263   925540      +      clpA    2277
# b0884     926224   926443      -      infA     219
# b0885     926727   927432      -       aat     705
# b0886     927473   929195      -      cydC    1722
# b0887     929195   930962      -      cydD    1767
# b0888     931084   932050      -      trxB     966
# b0889     932594   933089      +       lrp     495
# b0890     933223   937213      +      ftsK    3990
# b0891     937371   937983      +      lolA     612
# b0892     937993   939337      +      rarA    1344
# b0893     939427   940720      +      serS    1293
# b0894     940958   943403      +      dmsA    2445
# b0895     943413   944031      +      dmsB     618
# b0896     944032   944896      +      dmsC     864
# ...
# b4143    Posttranslational modification, protein turnov...
# b4144                                     Function unknown
# b4145                                     Function unknown
# b4146                  Amino acid transport and metabolism
# b4147      Translation, ribosomal structure and biogenesis
# b4410                                     Function unknown
# b4411                                     Function unknown
# b4148               Inorganic ion transport and metabolism
# b4149               Cell wall/membrane/envelope biogenesis
# b4150                                   Defense mechanisms
# b4151                     Energy production and conversion
# b4152                     Energy production and conversion
# b4153                     Energy production and conversion
# b4154                     Energy production and conversion
# b4155      Translation, ribosomal structure and biogenesis
# b4156                  Amino acid transport and metabolism
# b4157                                     Function unknown
# b4158                                     Function unknown
# b4159               Cell wall/membrane/envelope biogenesis
# b4160                       Lipid transport and metabolism
# b4161                                     Function unknown
# b4162                      RNA processing and modification
# b4670                                    No COG Annotation
# b4166                     Energy production and conversion
# b4167                Carbohydrate transport and metabolism
# b4168                                     Function unknown
# b4169               Cell wall/membrane/envelope biogenesis
# b4170                Replication, recombination and repair
# b4171      Translation, ribosomal structure and biogenesis
# b4172                       Signal transduction mechanisms
# b4173                                     Function unknown
# b4174    Posttranslational modification, protein turnov...
# b4175    Posttranslational modification, protein turnov...
# b4176                                     Function unknown
# b4177                  Nucleotide transport and metabolism
# b4178                                        Transcription
# b4179                                        Transcription
# b4180      Translation, ribosomal structure and biogenesis
# b4181                                     Function unknown
# b4182                                        Transcription
# b4183                                     Function unknown
# b4184                                     Function unknown
# b4185                                     Function unknown
# b4186                  Amino acid transport and metabolism
# b4187                       Lipid transport and metabolism
# b4188                                     Function unknown
# b4189                                    No COG Annotation
# b4190                                     Function unknown
# b4191                                        Transcription
# b4192                                     Function unknown
# b4193                Carbohydrate transport and metabolism
# b4194                Carbohydrate transport and metabolism
# b4195                Carbohydrate transport and metabolism
# b4196                Carbohydrate transport and metabolism
# b4197                Carbohydrate transport and metabolism
# b4198                Carbohydrate transport and metabolism
# b4199                                     Function unknown
# b4200      Translation, ribosomal structure and biogenesis
# b4201                Replication, recombination and repair
# b4202      Translation, ribosomal structure and biogenesis
# b4203      Translation, ribosomal structure and biogenesis
# b4204                                    No COG Annotation
# b4205                                    No COG Annotation
# b4206               Cell wall/membrane/envelope biogenesis
# b4207    Posttranslational modification, protein turnov...
# b4208                  Amino acid transport and metabolism
# b4209    Cell cycle control, cell division, chromosome ...
# b4210                                     Function unknown
# b4211                Carbohydrate transport and metabolism
# b4212                                        Transcription
# b4213                  Nucleotide transport and metabolism
# b4214               Inorganic ion transport and metabolism
# b4215                                    No COG Annotation
# b4216                                     Function unknown
# b4217                                     Function unknown
# b4218               Inorganic ion transport and metabolism
# b4219    Posttranslational modification, protein turnov...
# b4220               Cell wall/membrane/envelope biogenesis
# b4221                                     Function unknown
# b4222                                     Function unknown
# b4224                                        Transcription
# b4225                       Signal transduction mechanisms
# b4226                     Energy production and conversion
# b4227                Carbohydrate transport and metabolism
# b4485               Inorganic ion transport and metabolism
# b4230                                     Function unknown
# b4231                Carbohydrate transport and metabolism
# b4232                Carbohydrate transport and metabolism
# b4233               Cell wall/membrane/envelope biogenesis
# b4234                                     Function unknown
# b4235                                     Function unknown
# b4236                                    No COG Annotation
# b4237    Posttranslational modification, protein turnov...
# b4238                  Nucleotide transport and metabolism
# b4239                Carbohydrate transport and metabolism
# b4240                Carbohydrate transport and metabolism
# b4241                                        Transcription
# b4702                                    No COG Annotation
# b4242               Inorganic ion transport and metabolism
# b4243      Translation, ribosomal structure and biogenesis
# b4244                  Nucleotide transport and metabolism
# b4245                  Nucleotide transport and metabolism
# b4246                                    No COG Annotation
# b4248      Translation, ribosomal structure and biogenesis
# b4249                                     Function unknown
# b4251                                        Transcription
# b4252                Carbohydrate transport and metabolism
# b4253                                    No COG Annotation
# b4254                  Amino acid transport and metabolism
# b4255                                     Function unknown
# b4256                                     Function unknown
# b4257                                     Function unknown
# b4258      Translation, ribosomal structure and biogenesis
# b4259                Replication, recombination and repair
# b4260                  Amino acid transport and metabolism
# b4261                                     Function unknown
# b4262                                     Function unknown
# b4263                                     Function unknown
# b4264                                        Transcription
# b4265                  Amino acid transport and metabolism
# b4266                                     Function unknown
# b4267                  Amino acid transport and metabolism
# b4268                Carbohydrate transport and metabolism
# b4269                     Energy production and conversion
# b4271                                    No COG Annotation
# b4272                Replication, recombination and repair
# b4273                Replication, recombination and repair
# b4575_2                                  No COG Annotation
# b4575_1                                  No COG Annotation
# b4277                                    No COG Annotation
# b4278                Replication, recombination and repair
# b4279                Carbohydrate transport and metabolism
# b4280                                     Function unknown
# b4655                                    No COG Annotation
# b4281                                    No COG Annotation
# b4282                                    No COG Annotation
# b4623_1                                  No COG Annotation
# b4284                Replication, recombination and repair
# b4561                                    No COG Annotation
# b4623_2                                  No COG Annotation
# b4623_3                                  No COG Annotation
# b4286                                    No COG Annotation
# b4287               Inorganic ion transport and metabolism
# b4288               Inorganic ion transport and metabolism
# b4289               Inorganic ion transport and metabolism
# b4290                                    No COG Annotation
# b4291               Inorganic ion transport and metabolism
# b4292                       Signal transduction mechanisms
# b4293                                        Transcription
# b4294                Replication, recombination and repair
# b4576                                    No COG Annotation
# b4295                                        Transcription
# b4296                  Amino acid transport and metabolism
# b4297                  Amino acid transport and metabolism
# b4298                  Amino acid transport and metabolism
# b4299                                    No COG Annotation
# b4300                                        Transcription
# b4301                Carbohydrate transport and metabolism
# b4302                Carbohydrate transport and metabolism
# b4303                                     Function unknown
# b4304                Carbohydrate transport and metabolism
# b4565                Carbohydrate transport and metabolism
# b4305                  Amino acid transport and metabolism
# b4656                                    No COG Annotation
# b4306                                     Function unknown
# b4307                                     Function unknown
# b4566                                     Function unknown
# b4657                                    No COG Annotation
# b4308_1                                  No COG Annotation
# b4308_2                                  No COG Annotation
# b4309                                    No COG Annotation
# b4310                                     Function unknown
# b4311                Carbohydrate transport and metabolism
# b4312                Replication, recombination and repair
# b4313                Replication, recombination and repair
# b4314                                     Function unknown
# b4315                                        Cell motility
# b4316    Posttranslational modification, protein turnov...
# b4317               Cell wall/membrane/envelope biogenesis
# b4318                                     Function unknown
# b4319                                     Function unknown
# b4320                                     Function unknown
# b4321                  Amino acid transport and metabolism
# b4322                Carbohydrate transport and metabolism
# b4323                Carbohydrate transport and metabolism
# b4324                                        Transcription
# b4325                                    No COG Annotation
# b4326                                        Transcription
# b4327                                        Transcription
# b4328                                     Function unknown
# b4329                                     Function unknown
# b4330                                     Function unknown
# b4331      Translation, ribosomal structure and biogenesis
# b4332                Carbohydrate transport and metabolism
# b4333                                     Function unknown
# b4334                       Lipid transport and metabolism
# b4335                  Amino acid transport and metabolism
# b4336                                     Function unknown
# b4337                Carbohydrate transport and metabolism
# b4339                                    No COG Annotation
# b4340                                        Transcription
# b4341                                     Function unknown
# b4342                                    No COG Annotation
# b4486                                    No COG Annotation
# b4345                                   Defense mechanisms
# b4346                                   Defense mechanisms
# b4347      Translation, ribosomal structure and biogenesis
# b4348                                   Defense mechanisms
# b4349                                   Defense mechanisms
# b4350                                   Defense mechanisms
# b4351                                   Defense mechanisms
# b4352                                     Function unknown
# b4353                                     Function unknown
# b4354                       Signal transduction mechanisms
# b4355                                     Function unknown
# b4356                Carbohydrate transport and metabolism
# b4357                                        Transcription
# b4358                  Amino acid transport and metabolism
# b4359               Cell wall/membrane/envelope biogenesis
# b4360                                     Function unknown
# b4361                Replication, recombination and repair
# b4362                Replication, recombination and repair
# b4363                                     Function unknown
# b4364                                     Function unknown
# b4365                                        Transcription
# b4366                       Signal transduction mechanisms
# b4367                                     Function unknown
# b4567                                     Function unknown
# b4371      Translation, ribosomal structure and biogenesis
# b4372                Replication, recombination and repair
# b4373                                     Function unknown
# b4374                                     Function unknown
# b4375      Translation, ribosomal structure and biogenesis
# b4376                                     Function unknown
# b4568                                    No COG Annotation
# b4377                                     Function unknown
# b4378                Replication, recombination and repair
# b4379    Posttranslational modification, protein turnov...
# b4380                                    No COG Annotation
# b4381                  Nucleotide transport and metabolism
# b4382                  Nucleotide transport and metabolism
# b4383                Carbohydrate transport and metabolism
# b4384                  Nucleotide transport and metabolism
# b4385                                    No COG Annotation
# b4386                    Coenzyme transport and metabolism
# b4387                                     Function unknown
# b4388                  Amino acid transport and metabolism
# b4389    Posttranslational modification, protein turnov...
# b4390                                        Transcription
# b4391                                     Function unknown
# b4392               Cell wall/membrane/envelope biogenesis
# b4393                                        Transcription
# b4394                                     Function unknown
# b4395                Carbohydrate transport and metabolism
# b4396                                        Transcription
# b4397                                     Function unknown
# b4398                       Signal transduction mechanisms
# b4399                       Signal transduction mechanisms
# b4400                                   Defense mechanisms
# b4401                       Signal transduction mechanisms
# b4402                                     Function unknown
# b4403      Translation, ribosomal structure and biogenesis
