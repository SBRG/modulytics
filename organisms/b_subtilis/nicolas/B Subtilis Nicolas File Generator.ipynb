# %% [markdown]
# # Nicolas File Generator
#
# This notebook generates all files for the Modulytics web page of Bacillus subtilis, based on ICA of Nicolas, et al., 2012 database

# %%
import sys
# be sure that this point to a clone of github.com/SBRG/ICA
sys.path.append('../../../../ica/')
from icaviz.plotting import *
DATA_DIR = 'data_files/'
GENE_DIR = '../annotation/gene_files/'
enrich = pd.read_csv(DATA_DIR + 'curated_enrichments.csv', index_col=0)
names = enrich['name'].tolist()
ica_data = load_data(X=DATA_DIR+'log_tpm.csv',
                     S=DATA_DIR+'M.csv',
                     A=DATA_DIR+'A.csv',
                     metadata='sample_metadata.csv',
                     annotation=GENE_DIR+'gene_info.csv',
                     trn=GENE_DIR+'TRN.csv',
                     cutoff=1300, 
                     organism='bsubtilis')
ica_data.thresholds = enrich.threshold.to_dict()
pd.set_option('display.max_rows', None)

# %%
# get functions from py files
sys.path.append('../../../py')
from gene_table import *
from gene_histogram import *
from gene_scatter import *
from activity_bar import *
from regulon_venn import *
from regulon_scatter import *

# gene dashboards
from gene_activity_bar import *

import os

# %%
links = pd.read_csv('../annotation/gene_links.csv', index_col = 0, header=None).to_dict()[1]
sample_meta = ica_data.metadata.reset_index()
gene_info = pd.read_csv(GENE_DIR+'gene_info.csv', index_col = 0)
trn = pd.read_csv(GENE_DIR+'TRN.csv', index_col = 0)

# %%
# Bacillus has overly complicated strings for regulation
# E coli and future datasets: see any other file generator
# for a different version of this function
def tf_with_links(k, row):
    tf_str = row.TF

    if not(type(tf_str) == str):
        return tf_str

    # get a list of transcription factors
    def convert_to_link(tf):
        pre = 'http://subtiwiki.uni-goettingen.de/v3/gene/search/exact/'
        link = pre + tf
        return '<a href="' + link + '" target="_blank">'+ tf + '</a>'
    
    i = 0;
    res = ''
    while i < len(tf_str):
        if tf_str[i] in '[ ]+/':
            res += tf_str[i]
            i += 1
        else:
            tf = tf_str[i:].partition(']')[0].partition(' ')[0]
            res += convert_to_link(tf)
            i += len(tf)
    return res

# %% [markdown]
# ## Generate Files

# %%
# dataset_meta: Stores information for the header of the dataset page
num_genes = ica_data.X.shape[0]
num_samps = ica_data.X.shape[1]
num_conds = 0;
for n, g in ica_data.metadata.groupby(['condition_id', 'project_id']):
    num_conds += 1
num_ims = ica_data.S.shape[1]

dataset_meta = pd.Series({'Title':'<i>B. subtilis</i> Microarray',
                          'Organism': '<i>Bacillus subtilis</i>',
                          'Strain': '168/BSB1',
                          'Publication':'<a href="https://doi.org/10.1101/2020.04.26.062638">Rychel, et al., 2020</a>',
                          'Number of Samples': num_samps,
                          'Number of Unique Conditions': num_conds,
                          'Number of Genes':num_genes,
                          'Number of iModulons': num_ims})
dataset_meta.to_csv('dataset_meta.csv')
# Out:
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.

# %%
im_table = enrich[['name', 'Regulator', 'Function', 'Category', 'n_genes', 'precision', 'recall']]
im_table = im_table.rename(columns={'name':'Name'})
im_table.index.name = 'k'
im_table['category_num'] = enrich.new_idx
im_table.to_csv('iM_table.csv')

# %%
num_ims = im_table.shape[0]-1
file = open('num_ims.txt', 'w')
file.write(str(num_ims))
file.close()

# %%
enrich
# Out:
#                                                  name  \
# 1                                  FadR – Fatty Acids
# 6                                       MalR – Malate
# 38                                    GlpP – Glycerol
# 59                                    FruR – Fructose
# 72                          LevR – Levan and Fructose
# 61                                FrlR – Amino Sugars
# 30                                     ManR – Mannose
# 3                                      AcoR – Acetoin
# 80                                    LicR – Lichenan
# 82                             CcpA-1 – Low Glucose 1
# 10                             CcpA-2 – Low Glucose 2
# 52                          His – Histidine Synthesis
# 56                                    AhrC – Arginine
# 39                                  MtrB – Tryptophan
# 41                                 S-Box – Methionine
# 71   TnrA + CodY – Leucine, Methionine, and Threonine
# 2                              CodY – BCAA Limitation
# 75                       HutP – Histidine Utilization
# 60     RocR / PutR – Arginine and Proline Utilization
# 50                                 PyrR – Pyrimidines
# 58                                     PurR – Purines
# 70                                 Thi-Box – Thiamine
# 0                                 PchR – Pulcherrimin
# 57                              Fur – Iron Limitation
# 77                    PhoP-1 – Phosphate Limitation 1
# 74                    PhoP-2 – Phosphate Limitation 2
# 45                              Zur – Zinc Limitation
# 32                         CzrA – Toxic Cation Export
# 69                                      CymR – Sulfur
# 12                     Yrk – Putative Sulfur Carriers
# 9                            ResD – Oxygen Limitation
# 8                           Fnr – Nitrate Respiration
# 44                          Rex – Overflow Metabolism
# 49                                  LexA – DNA Repair
# 4                             SigW – Cell Wall Stress
# 47                             SigM – Membrane Stress
# 16                       Ybc – Uncharacterized Operon
# 7                           SigB-1 – General Stress 1
# 46                          SigB-2 – General Stress 2
# 21                               StrRes – Translation
# 23                                    SigD – Motility
# 5                       Eps – Exopolymeric Substances
# 53                                 ComA – Surfactants
# 54             DegU – Toxins and Colony Establishment
# 36                            AbrB – Transition State
# 79                    Alb – Antilisterial Bacteriocin
# 14                   WapA – Intercellular Competition
# 51                                  ComK – Competence
# 35                              Spo0A – Sporulation 1
# 48                               SigE – Sporulation 2
# 68                           SigE / G – Sporulation 3
# 66                               SigG – Sporulation 4
# 13                             SigK-1 – Sporulation 5
# 25                             SigK-2 – Sporulation 6
# 15                  GerE / GerR – Mid-late Spore Coat
# 65                                Xpf – PBSX Prophage
# 22                            Spβ-1 – SP-β Prophage 1
# 64                            Spβ-2 – SP-β Prophage 2
# 18                                      ImmR – ICEBs1
# 27                                SknR – Skin Element
# 20     IolR / MelR – Inositol, Melibiose, and Acetoin
# 40                       NadR / BirA – NAD and Biotin
# 81  MtlR / AnsR – Mannitol, Asparagine, and Aspartate
# 73                  TnrA / PucR – Nitrogen Limitation
# 67       CymR / NsrR – Sulfur and Nitrate Respiration
# 11                             ArsR+ – Diamide Stress
# 17                                  Uncharacterized 1
# 43                                  Uncharacterized 2
# 33                                  Uncharacterized 3
# 34                                  Uncharacterized 4
# 24                                  Uncharacterized 5
# 26                                  Uncharacterized 6
# 62                                       Noise – S144
# 28                                       Noise – S415
# 29                                      Noise – S1235
# 31                                      Noise – S1210
# 42                 Noise – Carbon Source Transition 1
# 63                 Noise – Carbon Source Transition 2
# 55                                   Noise – LBGexp_1
# 37                                 Noise – Diamide 15
# 19                                            Empty 1
# 76                                            Empty 2
# 78                                            Empty 3
#
#                                                    TF  high_conf  precision  \
# 1                                                FadR          1   1.000000
# 6                                                MalR          1   1.000000
# 38                                               GlpP          1   1.000000
# 59                                               FruR          1   1.000000
# 72                                               LevR          1   1.000000
# 61                                               FrlR          1   1.000000
# 30                                               ManR          1   1.000000
# 3                                                AcoR          1   1.000000
# 80                                               LicR          1   0.444444
# 82                                        CcpA + SigA          0   0.794872
# 10                             [CcpA + SigA] / [CcpN]          0   0.611765
# 52                                               YlxR          1   1.000000
# 56                                        AhrC + YlxR          1   0.666667
# 39                                               MtrB          1   1.000000
# 41                                              S-box          1   0.840000
# 71  [TnrA + CodY + ThrR] / [TnrA + CodY + T-box + ...          1   0.423077
# 2                                                CodY          1   0.875000
# 75                                               HutP          1   1.000000
# 60  [SigL + AhrC + RocR] / [Spo0A + SigA + CodY + ...          1   0.923077
# 50                                               PyrR          1   1.000000
# 58                                               PurR          1   1.000000
# 70                                            Thi-box          1   1.000000
# 0                                                PchR          1   0.857143
# 57                                                Fur          1   0.890909
# 77                                        PhoP + SigA          1   0.727273
# 74                                        PhoP + SigA          1   0.954545
# 45                                                Zur          1   1.000000
# 32                                               CzrA          1   1.000000
# 69                                               CymR          1   0.755556
# 12                                                NaN          0   0.000000
# 9                                                ResD          0   0.434211
# 8                                          Fnr + SigA          1   0.888889
# 44                                                Rex          1   0.900000
# 49                                               LexA          1   0.777778
# 4                                                SigW          1   0.940000
# 47                                               SigM          1   0.954545
# 16                                                NaN          0   0.000000
# 7                                                SigB          1   0.864407
# 46                                               SigB          1   0.600000
# 21                      [stringent response] / [RplJ]          1   1.000000
# 23                                               SigD          1   0.914894
# 5                           SigA + AbrB + RemA + SinR          1   1.000000
# 53  [ComA + CcpA + TnrA] / [Abh + SigA + ComA + Sp...          1   1.000000
# 54                                               DegU          0   0.325000
# 36                                               AbrB          1   0.833333
# 79                           Rok + ResD + AbrB + SigA          1   0.666667
# 14                         SigA + YvrHb + DegU + WalR          0   0.176471
# 51                                               ComK          1   0.612245
# 35                                   [Spo0A] / [DnaA]          0   0.800000
# 48                                               SigE          0   0.638710
# 68                                    [SigE] / [SigG]          0   0.794118
# 66                                               SigG          0   0.620915
# 13                                               SigK          0   0.618705
# 25                                               SigK          0   0.556701
# 15                      [SigK + GerE] / [SigK + GerR]          0   0.764706
# 65                                                Xpf          1   0.878788
# 22                                                NaN          0   0.000000
# 64                          CsoR + SigA + SigK + SigE          0   0.093960
# 18                                               ImmR          1   0.950000
# 27                                               SknR          0   0.352941
# 20                           [IolR] / [MelR] / [AcoR]          1   0.896552
# 40                                    [NadR] / [BirA]          1   0.681818
# 81                             [MtlR] / [AnsR + SigA]          1   0.727273
# 73                      [SigA + TnrA] / [SigA + PucR]          1   0.900000
# 67               [SigA + CymR] / [ResD + SigA + NsrR]          1   0.909091
# 11    [ArsR] / [YodB] / [SigA + CtsR] / [SigA + CsoR]          0   0.466667
# 17                                                NaN          0        NaN
# 43                                                NaN          0        NaN
# 33                                                NaN          0        NaN
# 34                                                NaN          0        NaN
# 24                                                NaN          0        NaN
# 26                                                NaN          0        NaN
# 62                                                NaN          0        NaN
# 28                                                NaN          0        NaN
# 29                                                NaN          0        NaN
# 31                                                NaN          0        NaN
# 42                                                NaN          0        NaN
# 63                                                NaN          0        NaN
# 55                                                NaN          0        NaN
# 37                                                NaN          0        NaN
# 19                                                NaN          0        NaN
# 76                                                NaN          0        NaN
# 78                                                NaN          0        NaN
#
#       recall          reg_type  \
# 1   0.739130      well defined
# 6   1.000000      well defined
# 38  1.000000      well defined
# 59  1.000000      well defined
# 72  1.000000      well defined
# 61  1.000000      well defined
# 30  1.000000      well defined
# 3   0.750000      well defined
# 80  0.800000  contains unknown
# 82  0.126531            subset
# 10  0.203922     closest match
# 52  0.186047    subset, operon
# 56  1.000000      well defined
# 39  0.555556    subset, operon
# 41  0.525000            subset
# 71  1.000000  contains unknown
# 2   0.148936            subset
# 75  0.857143      well defined
# 60  0.800000      well defined
# 50  0.785714      well defined
# 58  0.666667      well defined
# 70  0.833333      well defined
# 0   0.600000            subset
# 57  0.597561            subset
# 77  0.114286            subset
# 74  0.300000            subset
# 45  0.923077      well defined
# 32  0.833333      well defined
# 69  0.693878      well defined
# 12  0.000000           unknown
# 9   0.478261     closest match
# 8   0.888889      well defined
# 44  0.529412            subset
# 49  0.272727            subset
# 4   0.435185            subset
# 47  0.162791            subset
# 16  0.000000           unknown
# 7   0.323810            subset
# 46  0.095238     closest match
# 21  0.260000            subset
# 23  0.573333            subset
# 5   0.950000      well defined
# 53  1.000000      well defined
# 54  0.122642     closest match
# 36  0.106667            subset
# 79  0.800000      well defined
# 14  1.000000  contains unknown
# 51  0.405405     closest match
# 35  0.051724            subset
# 48  0.327815     closest match
# 68  0.113924            subset
# 66  0.524862     closest match
# 13  0.480447     closest match
# 25  0.301676     closest match
# 15  0.127451            subset
# 65  1.000000      well defined
# 22  0.000000           unknown
# 64  0.933333  contains unknown
# 18  0.950000      well defined
# 27  0.500000     closest match
# 20  0.928571      well defined
# 40  0.714286      well defined
# 81  0.800000      well defined
# 73  0.169811            subset
# 67  0.338983            subset
# 11  0.280000     closest match
# 17       NaN               NaN
# 43       NaN               NaN
# 33       NaN               NaN
# 34       NaN               NaN
# 24       NaN               NaN
# 26       NaN               NaN
# 62       NaN               NaN
# 28       NaN               NaN
# 29       NaN               NaN
# 31       NaN               NaN
# 42       NaN               NaN
# 63       NaN               NaN
# 55       NaN               NaN
# 37       NaN               NaN
# 19       NaN               NaN
# 76       NaN               NaN
# 78       NaN               NaN
#
#                                              Function           Category  \
# 1                              Fatty acid degradation             Carbon
# 6                       Malate uptake and utilization             Carbon
# 38                    Glycerol uptake and utilization             Carbon
# 59                    Fructose uptake and utilization             Carbon
# 72  Fuctose uptake and phosphorylation, degradatio...             Carbon
# 61                  Amino sugar uptake and metabolism             Carbon
# 30  Utilization of mannose for cell wall synthesis...             Carbon
# 3   Utilization of acetoin, extracellular energy s...             Carbon
# 80  Uptake, phosphorylation, and utilization of le...             Carbon
# 82  Uptake and utilization of alternative carbon s...             Carbon
# 10  Uptake, utilization, and regulation of alterna...             Carbon
# 52                             Synthesis of histidine        Amino Acids
# 56                Uptake and biosynthesis of arginine        Amino Acids
# 39                         Biosynthesis of tryptophan        Amino Acids
# 41                Methionine salvage and biosynthesis        Amino Acids
# 71  Synthesis and salvage of leucine, methionine, ...        Amino Acids
# 2   Uptake of di-/oligopeptides, uptake of guanosi...        Amino Acids
# 75                   Histidine uptake and utilization        Amino Acids
# 60  Utilization of arginine, ornithine, citrulline...        Amino Acids
# 50                           Synthesis of pyrimidines     Other Organics
# 58  Synthesis of purine, xanthine and guanine upta...     Other Organics
# 70                   Synthesis and uptake of thiamine     Other Organics
# 0   Extracellular synthesis and import of pulcherr...           Elements
# 57  Production and transport of siderophores for i...           Elements
# 77  High-affinity phosphate uptake, teichuronic ac...           Elements
# 74  Degradation of wall teichoic acid to salvage p...           Elements
# 45  Zinc uptake, zinc metallochaperones, alternati...           Elements
# 32               Resistance to Zn, Cu, Co, Ni, and Cd           Elements
# 69  Sulfur metabolism in response to oxidative str...           Elements
# 12  Putative sulfur carriers. High activity under ...           Elements
# 9   Anaerobic nitrate respiration, bacteriocin pro...  Oxygen Limitation
# 8           Nitrate respiration and nitrite extrusion  Oxygen Limitation
# 44  Overflow metabolism (LDH) and cytochrome BD ox...  Oxygen Limitation
# 49         SOS response for DNA protection and repair             Stress
# 4   Adaptation to membrane active agents such as c...             Stress
# 47  General stress proteins, alarmones, lipid carr...             Stress
# 16  Contains one subunit of NADH dehydrogenase wit...             Stress
# 7   Survival of general stressors including ethano...             Stress
# 46  Likely accounting for microarray saturation in...             Stress
# 21  Production of ribosomes, translation initiatio...         Lifestyles
# 23  Production of flagella components and export m...         Lifestyles
# 5   Biosynthesis of tasA and extracellular polysac...         Lifestyles
# 53  Activated during transition to stationary phas...         Lifestyles
# 54  Response to arrested flagellar motor. Secretio...         Lifestyles
# 36  Various transition state roles: spore killing,...         Lifestyles
# 79  Produces and exports subtilosin, which kills a...         Lifestyles
# 14  Activation of WapA and its operon of unknown g...         Lifestyles
# 51  DNA transport, pseudopilus, recombination mach...         Lifestyles
# 35  Initiation of sporulation through sigma factor...        Sporulation
# 48  Spore maturation through core dehydration, nut...        Sporulation
# 68  Spore coat production, transcription factor an...        Sporulation
# 66  Calcium and nutrient delivery to the spore, en...        Sporulation
# 13  Production of spore coat and crust proteins, L...        Sporulation
# 25  Production of outermost spore coat and crust p...        Sporulation
# 15  Production of spore coat and crust proteins. O...        Sporulation
# 65  Prophage element that induces production of ba...       Mobile Genes
# 22  Temperature-responsive SP-beta prophage. Respo...       Mobile Genes
# 64  Temperature-responsive SP-beta prophage. Proph...       Mobile Genes
# 18  Mobile genetic element that participates in ho...       Mobile Genes
# 27  Prophage element that disrupts the SigK gene b...       Mobile Genes
# 20  Uptake and utilization of inositol, melibiose/...      Multi-Purpose
# 40  Biosynthesis of NAD and biotin, plus safA & co...      Multi-Purpose
# 81  Uptake and utilization of mannitol, degradatio...      Multi-Purpose
# 73  Ammonium uptake, utilization of nitrate and xa...      Multi-Purpose
# 67  Import and utilization of sulfonate and cystin...      Multi-Purpose
# 11  Detoxification in response to: oxidative prote...      Multi-Purpose
# 17  Contains a SigE/SigG inhibitor, spore coat pro...    Uncharacterized
# 43  Contains cold shock, sporulation onset, toxin,...    Uncharacterized
# 33  Contains many poorly characterized RNAs with n...    Uncharacterized
# 34  Contains many poorly characterized RNAs with n...    Uncharacterized
# 24  Contains many poorly characterized RNAs with n...    Uncharacterized
# 26       5’ ends of tRNAs and independent transcripts    Uncharacterized
# 62  Likely accounting for noisey RNA S144, an inde...    Uncharacterized
# 28                  Noisy independent transcript S415    Uncharacterized
# 29  Independent transcript S1235, behaves similar ...    Uncharacterized
# 31                 Noisy independent transcript S1210    Uncharacterized
# 42  Likely accounting for noise in the carbon sour...    Uncharacterized
# 63  Likely accounting for noise in carbon source t...    Uncharacterized
# 55  Likely accounting for noise in the first sampl...    Uncharacterized
# 37  Likely accounting for noise in the diamide aft...    Uncharacterized
# 19                                  Contains no genes    Uncharacterized
# 76                                  Contains no genes    Uncharacterized
# 78                                  Contains no genes    Uncharacterized
#
#                    category2                        category3  new_idx  \
# 1              Carbon Source                      Fatty Acids        0
# 6              Carbon Source                           Malate        1
# 38             Carbon Source                         Glycerol        2
# 59             Carbon Source                         Fructose        3
# 72             Carbon Source                         Fructose        4
# 61             Carbon Source                     Amino Sugars        5
# 30             Carbon Source                          Mannose        6
# 3              Carbon Source                          Acetoin        7
# 80             Carbon Source                         Lichenan        8
# 82            General Carbon             Low glucose response        9
# 10            General Carbon             Low glucose response       10
# 52      Amino Acid Synthesis              Specific: Histidine       11
# 56      Amino Acid Synthesis               Specific: Arginine       12
# 39      Amino Acid Synthesis             Specific: Tryptophan       13
# 41      Amino Acid Synthesis             Specific: Methionine       14
# 71      Amino Acid Synthesis                          Several       15
# 2       Amino Acid Synthesis                          Several       16
# 75            Amino Acid Use                        Histidine       17
# 60            Amino Acid Use                           Energy       18
# 50               Nucleotides                      Pyrimidines       19
# 58               Nucleotides                          Purines       20
# 70                 Cofactors                         Thiamine       21
# 0            Ion Homeostasis                             Iron       22
# 57           Ion Homeostasis                             Iron       23
# 77           Ion Homeostasis                        Phosphate       24
# 74           Ion Homeostasis                        Phosphate       25
# 45           Ion Homeostasis                             Zinc       26
# 32           Ion Homeostasis                    Toxic Cations       27
# 69        Sulfur Homeostasis                 Oxidative Stress       28
# 12        Sulfur Homeostasis                         Putative       29
# 9          Oxygen Limitation               Pleiotropic Energy       30
# 8          Oxygen Limitation              Nitrate Respiration       31
# 44         Oxygen Limitation                         Overflow       32
# 49        Specific Stressors                       DNA Damage       33
# 4         Specific Stressors             Wall/Membrane Stress       34
# 47        Specific Stressors             Wall/Membrane Stress       35
# 16        Specific Stressors              Possible Heat Shock       36
# 7             General Stress                   General Stress       37
# 46            General Stress                   General Stress       38
# 21               Translation                      Translation       39
# 23                  Motility                         Motility       40
# 5                   Biofilms                              NaN       41
# 53                  Biofilms                              NaN       42
# 54                  Biofilms                              NaN       43
# 36                  Biofilms                              NaN       44
# 79          Toxin Production                              NaN       45
# 14          Toxin Production                              NaN       46
# 51                Competence                              NaN       47
# 35               Sporulation                                0       48
# 48               Sporulation                                1       49
# 68               Sporulation                                2       50
# 66               Sporulation                                3       51
# 13               Sporulation                                5       52
# 25               Sporulation                                6       53
# 15               Sporulation                                4       54
# 65     Deleterious Prophages                             PBSX       55
# 22     Deleterious Prophages                           SPBeta       56
# 64     Deleterious Prophages                           SPBeta       57
# 18           Other Prophages                              NaN       58
# 27           Other Prophages                              NaN       59
# 20  Multi-Purpose Metabolism         Several Specific Sources       60
# 40  Multi-Purpose Metabolism                      NAD, Biotin       61
# 81  Multi-Purpose Metabolism  Mannitol, Asparagine, Aspartate       62
# 73  Multi-Purpose Metabolism                    Nitrogen Ions       63
# 67  Multi-Purpose Metabolism                Sulfur Limitation       64
# 11      Multi-Purpose Stress                 Oxidative Stress       65
# 17     Noisy Groups of Genes                              NaN       66
# 43     Noisy Groups of Genes                              NaN       67
# 33     Noisy Groups of Genes                   Putative Noise       68
# 34     Noisy Groups of Genes                   Putative Noise       69
# 24     Noisy Groups of Genes                   Putative Noise       70
# 26     Noisy Groups of Genes                   Putative Noise       71
# 62               Noisy Genes                       Single RNA       72
# 28               Noisy Genes                       Single RNA       73
# 29               Noisy Genes                       Single RNA       74
# 31               Noisy Genes                       Single RNA       75
# 42               Noisy Genes                          Samples       76
# 63               Noisy Genes                          Samples       77
# 55               Noisy Genes                          Samples       78
# 37               Noisy Genes                          Samples       79
# 19                     Empty                              NaN       80
# 76                     Empty                              NaN       81
# 78                     Empty                              NaN       82
#
#                                             Regulator  threshold  n_genes
# 1                                                FadR   0.087360     17.0
# 6                                                MalR   0.144234      5.0
# 38                                               GlpP   0.106678     10.0
# 59                                               FruR   0.206403      4.0
# 72                                               LevR   0.142297      6.0
# 61                                               FrlR   0.127036      7.0
# 30                                               ManR   0.119812      6.0
# 3                                                AcoR   0.153858      3.0
# 80                                               LicR   0.076635      9.0
# 82                                        CcpA + SigA   0.057071     39.0
# 10                             [CcpA + SigA] / [CcpN]   0.045382     85.0
# 52                                               YlxR   0.129423      8.0
# 56                                        AhrC + YlxR   0.105072     15.0
# 39                                               MtrB   0.174997      5.0
# 41                                              S-box   0.076127     25.0
# 71  [TnrA + CodY + ThrR] / [TnrA + CodY + T-box + ...   0.065844     26.0
# 2                                                CodY   0.065552     40.0
# 75                                               HutP   0.086899      6.0
# 60  [SigL + AhrC + RocR] / [Spo0A + SigA + CodY + ...   0.093177     13.0
# 50                                               PyrR   0.117698     11.0
# 58                                               PurR   0.089225     20.0
# 70                                            Thi-box   0.095194     15.0
# 0                                                PchR   0.081261      7.0
# 57                                                Fur   0.047500     55.0
# 77                                        PhoP + SigA   0.086751     11.0
# 74                                        PhoP + SigA   0.089585     22.0
# 45                                                Zur   0.104663     12.0
# 32                                               CzrA   0.155808      5.0
# 69                                               CymR   0.046438     45.0
# 12                                                NaN   0.126741      7.0
# 9                                                ResD   0.046826     76.0
# 8                                          Fnr + SigA   0.120142      9.0
# 44                                                Rex   0.081571     10.0
# 49                                               LexA   0.071558     27.0
# 4                                                SigW   0.061503     50.0
# 47                                               SigM   0.077209     22.0
# 16                                                NaN   0.162882      7.0
# 7                                                SigB   0.033604    118.0
# 46                                               SigB   0.057723     50.0
# 21                      [stringent response] / [RplJ]   0.062382     52.0
# 23                                               SigD   0.056403     94.0
# 5                           SigA + AbrB + RemA + SinR   0.116051     19.0
# 53  [ComA + CcpA + TnrA] / [Abh + SigA + ComA + Sp...   0.141925      7.0
# 54                                               DegU   0.065658     40.0
# 36                                               AbrB   0.053203     48.0
# 79                           Rok + ResD + AbrB + SigA   0.069789     12.0
# 14                         SigA + YvrHb + DegU + WalR   0.116118     17.0
# 51                                               ComK   0.050085     49.0
# 35                                   [Spo0A] / [DnaA]   0.076391     15.0
# 48                                               SigE   0.042301    155.0
# 68                                    [SigE] / [SigG]   0.049619     68.0
# 66                                               SigG   0.042330    153.0
# 13                                               SigK   0.034650    139.0
# 25                                               SigK   0.035362     97.0
# 15                      [SigK + GerE] / [SigK + GerR]   0.092769     17.0
# 65                                                Xpf   0.081181     33.0
# 22                                                NaN   0.100877      2.0
# 64                          CsoR + SigA + SigK + SigE   0.036485    149.0
# 18                                               ImmR   0.078043     20.0
# 27                                               SknR   0.052144     17.0
# 20                           [IolR] / [MelR] / [AcoR]   0.076520     29.0
# 40                                    [NadR] / [BirA]   0.098662     22.0
# 81                             [MtlR] / [AnsR + SigA]   0.091097     11.0
# 73                      [SigA + TnrA] / [SigA + PucR]   0.101788     10.0
# 67               [SigA + CymR] / [ResD + SigA + NsrR]   0.081852     22.0
# 11    [ArsR] / [YodB] / [SigA + CtsR] / [SigA + CsoR]   0.064922     30.0
# 17                                                NaN   0.065454     30.0
# 43                                                NaN   0.054663     40.0
# 33                                                NaN   0.048538     80.0
# 34                                                NaN   0.049752     62.0
# 24                                                NaN   0.069265     19.0
# 26                                                NaN   0.074451      6.0
# 62                                                NaN   0.217807      1.0
# 28                                                NaN   0.112846      2.0
# 29                                                NaN   0.122629      1.0
# 31                                                NaN   0.142092      1.0
# 42                                                NaN   0.073841     22.0
# 63                                                NaN   0.060006     30.0
# 55                                                NaN   0.055977     48.0
# 37                                                NaN   0.095907      5.0
# 19                                                NaN   0.126665      0.0
# 76                                                NaN   0.163114      0.0
# 78                                                NaN   0.123938      0.0

# %%
def make_directory(ica_data, k, row, links, sample_meta):
    # generate the plot files
    gene_table = gene_table_df(ica_data, k, row, links = links, operon_commas=False)
    gene_hist = gene_hist_df(ica_data, k, row)
    base_conds = ['M9exp_1', 'M9exp_2', 'M9exp_3']
    gene_scatter = gene_scatter_df(ica_data, k, base_conds, links)
    act_bar = activity_bar_df(ica_data, k, sample_meta)

    reg_venn = regulon_venn_df(ica_data, k, row)
    reg_scatter = regulon_scatter_df(ica_data, k, row)

    # generate a basic data df
    res = pd.Series(index=['name', 'TF', 'Regulator',
                           'Function', 'Category', 
                           'has_venn', 'scatter', 'has_meme',
                           'precision', 'recall'])
    res.loc['name'] = row.loc['name']
    res.loc['TF'] = row.TF
    res.loc['Regulator'] = tf_with_links(k, row)
    res.loc['Function'] = row.Function
    res.loc['Category'] = row.Category
    res.loc['has_venn'] = not(reg_venn is None)
    if reg_scatter is None:
        res.loc['scatter'] = 0
    else:
        res.loc['scatter'] = reg_scatter.shape[1] - 1
    res.loc['has_meme'] = False # update later
    res.loc['precision'] = row.precision
    res.loc['recall'] = row.recall

    # save output
    folder = 'iModulon_files/'+str(k)+'/'
    if not(os.path.isdir(folder)):
        os.mkdir(folder)
    res.to_csv(folder+str(k)+'_meta.csv')
    gene_table.to_csv(folder+str(k)+'_gene_table.csv')
    gene_hist.to_csv(folder+str(k)+'_gene_hist.csv')
    gene_scatter.to_csv(folder+str(k)+'_gene_scatter.csv')
    act_bar.to_csv(folder+str(k)+'_activity_bar.csv')
    if not(reg_venn is None):
        reg_venn.to_csv(folder+str(k)+'_reg_venn.csv')
    if not(reg_scatter is None):
        reg_scatter.to_csv(folder+str(k)+'_reg_scatter.csv')
    ica_data.S[k].to_csv(folder+str(k)+'_gene_weights.csv')
    ica_data.A.loc[k].to_csv(folder+str(k)+'_activity.csv')

# %%
for k, row in enrich.iterrows():
    make_directory(ica_data, k, row, links, sample_meta)
# Out:
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ...
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /home/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ../../../py/gene_scatter.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.link[g] = links[g]

# %% [markdown]
# # Gene Files

# %%
# Filter out genes with no ICA data
reduced_gene_info = gene_info.copy()
reduced_gene_info = reduced_gene_info[reduced_gene_info.index.isin(ica_data.X.index)]

# %%
# Information for Gene Metadata

def make_gene_files(ica_data, k, row, links, sample_meta):

    # generate metadata df
    res = pd.Series(index=['gene_id', 'name', 'operon', 'product',
                           'cog', 'regulator(s)', 'link'])
    res.loc['gene_id'] = k
    res.loc['name'] = row.gene_name
    res.loc['operon'] = row.operon
    res.loc['product'] = row['product']
    res.loc['cog'] = row.cog
    res.loc['regulator(s)'] = ", ".join(trn[trn.gene_id == k].TF.to_list())
    try:
        res.loc['link'] = '<a href="' + str(links[k]) + '">'+ 'SubtiWiki' + '</a>'
    except:
        res.loc['link'] = None
    res.fillna(value="<i> Not Available </i>", inplace = True) 
    
    # save output
    folder = 'gene_page_files/'+str(k)+'/'
    if not(os.path.isdir(folder)):
        os.mkdir(folder)
    res.to_csv(folder+str(k)+'_meta.csv')

# %%
# generate metadata csv for each gene
for k, row in reduced_gene_info.iterrows():
    make_gene_files(ica_data, k, row, links, sample_meta)
# Out:
# /home/katherine/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7 DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.

# %%
# activity plot + expression for each gene
for gene_id in reduced_gene_info.index:
    this_fig = gene_activity_bar_df(ica_data, gene_id, sample_meta)
    folder = 'gene_page_files/'+str(gene_id)+'/'
    this_fig.to_csv(folder + gene_id + '_activity_bar.csv')
    ica_data.X.loc[gene_id].to_csv(folder+gene_id+'_expression.csv')

# %%
# table for each gene

# generate df with all iM genes indicated T/F 
im_genes= ica_data.S.T.copy()
for k,row in ica_data.S.T.iterrows():
    im_genes.loc[k,:] = abs(row) > abs(ica_data.thresholds[k])
    
# iM_table: start with main component of iM page
im_table = enrich[['name', 'Regulator', 'Function', 'Category']]
im_table = im_table.rename(columns={'name':'Name'})
im_table.index.name = 'k'

#loop through genes:
for gene_id in reduced_gene_info.index:
    perGene_table = im_table.copy()
    perGene_table.insert(column ='in_iM', value = im_genes.loc[:, gene_id], loc = 1)
    perGene_table.insert(column ='gene_weight', value = ica_data.S.loc[gene_id, :], loc = 2)

    #sort
    perGene_table = (perGene_table.assign(A=perGene_table['gene_weight'].abs())
            .sort_values(['in_iM','A'],ascending=[False, False])
            .drop('A', 1))
    folder = 'gene_page_files/'+str(gene_id)+'/'
    perGene_table.to_csv(folder + gene_id + '_perGene_table.csv')

# %% [markdown]
# ### make json file for Search

# %% [markdown]
# #### Genes

# %%
# Get df in correct format
gene_df = reduced_gene_info.copy()
gene_df["gene_id"] = reduced_gene_info.index
gene_df = gene_df[['gene_name', "gene_id", "product"]]
gene_df = gene_df.sort_values(by="gene_name")
gene_df["gene_name"] = gene_df["gene_name"].fillna(value = "Unnamed Gene")
gene_df["product"] = gene_df["product"].fillna(value = "not available")

#create gene info json
gene_df.to_json('./gene_page_files/gene_list.json', orient="records")

# %% [markdown]
# #### iModulons

# %%
enrich_df = enrich.copy()
enrich_df['component'] = enrich_df.index
enrich_df = enrich_df[['component', 'name', 'Regulator', 'Function']]
enrich_df = enrich_df.sort_values(by="name").fillna(value = "N/A")

enrich_df.to_json('./iModulon_files/im_list.json', orient="records")
